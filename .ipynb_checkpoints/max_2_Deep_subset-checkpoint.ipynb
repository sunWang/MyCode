# %%
import time
import os


import numpy as np
import pandas as pd

import datetime as dt
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import GridSearchCV,train_test_split



from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.externals import joblib

from sklearn.linear_model import LinearRegression
from sklearn import svm
from sklearn.ensemble import RandomForestRegressor

from sklearn.ensemble import GradientBoostingRegressor

from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
from sklearn import preprocessing


import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping

# %%
path = 'max_data/SixAirlinesDataV2.csv'
data = pd.read_csv(path, sep = ',', na_filter = False)
#data = data.set_index('id')
data=data.drop(columns='Unnamed: 0')
data.head()
# Out:
#     Airline  Aircraft  FlightDuration  IsInternational  SeatsEconomy  \
# 0  0.089142 -0.693889       -0.817844         3.294215     -0.436182
# 1  0.089142 -0.693889       -0.783876         3.294215     -1.029628
# 2  0.648468 -0.693889       -1.199981        -0.303562     -0.554871
# 3  0.089142  1.441153       -1.542489         3.294215     -1.108754
# 4  1.207793 -0.693889       -0.161134        -0.303562     -0.053740
#
#    SeatsPremium  PitchEconomy  PitchPremium  WidthEconomy  WidthPremium  \
# 0     -0.343385      1.220342     -2.215259      0.302148     -1.357472
# 1     -1.147585      1.220342     -2.968588     -1.455802     -2.258698
# 2     -1.878677     -1.818641      1.551387     -1.455802      1.346207
# 3     -1.147585      1.220342     -2.968588     -1.455802     -2.258698
# 4     -0.416494      1.220342      0.044729     -1.455802     -0.456246
#
#    PriceEconomy  PricePremium  PriceRelative  SeatsTotal  PitchDifference  \
# 0     -0.578401     -0.802415           0.06   -0.442612        -2.091811
# 1     -0.667926     -0.870953           0.07   -1.098823        -2.650559
# 2     -1.010589     -1.018270           0.65   -0.794154         1.819422
# 3     -1.141274     -1.256183           0.09   -1.169131        -2.650559
# 4      1.630900      1.014233           0.07   -0.114507        -0.415569
#
#    WidthDifference  PercentPremiumSeats  month_num
# 0        -1.381970             0.009871  -1.639972
# 1        -1.381970            -0.411592  -1.639972
# 2         1.912112            -2.053194   0.282340
# 3        -1.381970            -0.297797   0.282340
# 4         0.265071            -0.457953  -0.678816

# %%
# variables seleccionadas según diferentes criterios  根据不同标准选择变量
Y = data[['PriceEconomy']].copy()
Y = Y.values
X = data.drop(columns = ['PriceEconomy']).copy()
X = X.values

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
# shuffle and split data into train (~80%) and test (~20%)
X_train, X_test, y_train, y_test = train_test_split(X_scale, Y, 
                                                    test_size=0.2, random_state=42) 

print('training data shape: ',X_train.shape)
print('testing data shape: ',X_test.shape)
# Out:
# training data shape:  (256, 17)
# testing data shape:  (64, 17)

# %%
#get number of columns in training data
n_cols = X_train.shape[1]

# builds model
model = keras.Sequential()

model.add(keras.layers.Dense(150, activation=tf.nn.relu, 
                       input_shape=(n_cols,)))
model.add(keras.layers.Dense(150, activation=tf.nn.relu))
model.add(keras.layers.Dense(150, activation=tf.nn.relu))
model.add(keras.layers.Dense(150, activation=tf.nn.relu))
model.add(keras.layers.Dense(150, activation=tf.nn.relu))
model.add(keras.layers.Dense(1))

#compile model
model.compile(loss='mse', optimizer='adam', metrics=['mae']) # use metric as mean absolute error

#inspect the model
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_54 (Dense)             (None, 150)               2700
# _________________________________________________________________
# dense_55 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_56 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_57 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_58 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_59 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 93,451
# Trainable params: 93,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train model and perform validation test

early_stop = EarlyStopping(monitor='val_loss', patience=15) # stops training when it doesn't show improvemnet.

history = model.fit(X_train, y_train, epochs=300, 
          validation_split=0.2, verbose=1, callbacks=[early_stop])
# Out:
# Train on 204 samples, validate on 52 samples
# Epoch 1/300
# 204/204 [==============================] - 1s 3ms/sample - loss: 0.8725 - mean_absolute_error: 0.7839 - val_loss: 0.6875 - val_mean_absolute_error: 0.6733
# Epoch 2/300
# 204/204 [==============================] - 0s 183us/sample - loss: 0.5589 - mean_absolute_error: 0.6081 - val_loss: 0.3931 - val_mean_absolute_error: 0.4827
# Epoch 3/300
# 204/204 [==============================] - 0s 159us/sample - loss: 0.2865 - mean_absolute_error: 0.4363 - val_loss: 0.2435 - val_mean_absolute_error: 0.3976
# Epoch 4/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.1709 - mean_absolute_error: 0.3210 - val_loss: 0.1612 - val_mean_absolute_error: 0.3107
# Epoch 5/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.1157 - mean_absolute_error: 0.2506 - val_loss: 0.0866 - val_mean_absolute_error: 0.2317
# Epoch 6/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0585 - mean_absolute_error: 0.1682 - val_loss: 0.0668 - val_mean_absolute_error: 0.2005
# Epoch 7/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0431 - mean_absolute_error: 0.1505 - val_loss: 0.0534 - val_mean_absolute_error: 0.1641
# Epoch 8/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0323 - mean_absolute_error: 0.1260 - val_loss: 0.0310 - val_mean_absolute_error: 0.1384
# Epoch 9/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0253 - mean_absolute_error: 0.1146 - val_loss: 0.0264 - val_mean_absolute_error: 0.1258
# Epoch 10/300
# 204/204 [==============================] - 0s 235us/sample - loss: 0.0189 - mean_absolute_error: 0.1015 - val_loss: 0.0223 - val_mean_absolute_error: 0.1150
# Epoch 11/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0188 - mean_absolute_error: 0.1072 - val_loss: 0.0188 - val_mean_absolute_error: 0.1120
# Epoch 12/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0168 - mean_absolute_error: 0.0989 - val_loss: 0.0255 - val_mean_absolute_error: 0.1301
# Epoch 13/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0191 - mean_absolute_error: 0.1083 - val_loss: 0.0122 - val_mean_absolute_error: 0.0893
# Epoch 14/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0155 - mean_absolute_error: 0.0987 - val_loss: 0.0163 - val_mean_absolute_error: 0.0991
# Epoch 15/300
# 204/204 [==============================] - ETA: 0s - loss: 0.0155 - mean_absolute_error: 0.087 - 0s 196us/sample - loss: 0.0125 - mean_absolute_error: 0.0864 - val_loss: 0.0173 - val_mean_absolute_error: 0.1053
# Epoch 16/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0102 - mean_absolute_error: 0.0773 - val_loss: 0.0103 - val_mean_absolute_error: 0.0815
# Epoch 17/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0089 - mean_absolute_error: 0.0767 - val_loss: 0.0103 - val_mean_absolute_error: 0.0820
# Epoch 18/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0088 - mean_absolute_error: 0.0746 - val_loss: 0.0116 - val_mean_absolute_error: 0.0870
# Epoch 19/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0073 - mean_absolute_error: 0.0686 - val_loss: 0.0104 - val_mean_absolute_error: 0.0802
# Epoch 20/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0109 - mean_absolute_error: 0.0840 - val_loss: 0.0144 - val_mean_absolute_error: 0.0985
# Epoch 21/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0086 - mean_absolute_error: 0.0749 - val_loss: 0.0109 - val_mean_absolute_error: 0.0829
# Epoch 22/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0106 - mean_absolute_error: 0.0814 - val_loss: 0.0071 - val_mean_absolute_error: 0.0658
# Epoch 23/300
# 204/204 [==============================] - 0s 137us/sample - loss: 0.0106 - mean_absolute_error: 0.0792 - val_loss: 0.0104 - val_mean_absolute_error: 0.0830
# Epoch 24/300
# 204/204 [==============================] - 0s 255us/sample - loss: 0.0079 - mean_absolute_error: 0.0705 - val_loss: 0.0143 - val_mean_absolute_error: 0.1006
# Epoch 25/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0090 - mean_absolute_error: 0.0745 - val_loss: 0.0154 - val_mean_absolute_error: 0.1030
# Epoch 26/300
# 204/204 [==============================] - 0s 274us/sample - loss: 0.0088 - mean_absolute_error: 0.0744 - val_loss: 0.0107 - val_mean_absolute_error: 0.0820
# Epoch 27/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0084 - mean_absolute_error: 0.0727 - val_loss: 0.0068 - val_mean_absolute_error: 0.0657
# Epoch 28/300
# 204/204 [==============================] - 0s 255us/sample - loss: 0.0069 - mean_absolute_error: 0.0660 - val_loss: 0.0133 - val_mean_absolute_error: 0.0963
# Epoch 29/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0059 - mean_absolute_error: 0.0614 - val_loss: 0.0073 - val_mean_absolute_error: 0.0688
# Epoch 30/300
# 204/204 [==============================] - 0s 235us/sample - loss: 0.0056 - mean_absolute_error: 0.0604 - val_loss: 0.0075 - val_mean_absolute_error: 0.0677
# Epoch 31/300
# 204/204 [==============================] - 0s 294us/sample - loss: 0.0050 - mean_absolute_error: 0.0555 - val_loss: 0.0076 - val_mean_absolute_error: 0.0710
# Epoch 32/300
# 204/204 [==============================] - 0s 255us/sample - loss: 0.0058 - mean_absolute_error: 0.0624 - val_loss: 0.0099 - val_mean_absolute_error: 0.0809
# Epoch 33/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0051 - mean_absolute_error: 0.0582 - val_loss: 0.0078 - val_mean_absolute_error: 0.0711
# Epoch 34/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0051 - mean_absolute_error: 0.0558 - val_loss: 0.0147 - val_mean_absolute_error: 0.1012
# Epoch 35/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0075 - mean_absolute_error: 0.0691 - val_loss: 0.0083 - val_mean_absolute_error: 0.0737
# Epoch 36/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0062 - mean_absolute_error: 0.0620 - val_loss: 0.0063 - val_mean_absolute_error: 0.0655
# Epoch 37/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0040 - mean_absolute_error: 0.0500 - val_loss: 0.0049 - val_mean_absolute_error: 0.0579
# Epoch 38/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0033 - mean_absolute_error: 0.0450 - val_loss: 0.0053 - val_mean_absolute_error: 0.0609
# Epoch 39/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0026 - mean_absolute_error: 0.0395 - val_loss: 0.0047 - val_mean_absolute_error: 0.0563
# Epoch 40/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0030 - mean_absolute_error: 0.0431 - val_loss: 0.0070 - val_mean_absolute_error: 0.0694
# Epoch 41/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0035 - mean_absolute_error: 0.0466 - val_loss: 0.0090 - val_mean_absolute_error: 0.0758
# Epoch 42/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0053 - mean_absolute_error: 0.0589 - val_loss: 0.0086 - val_mean_absolute_error: 0.0761
# Epoch 43/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0057 - mean_absolute_error: 0.0604 - val_loss: 0.0097 - val_mean_absolute_error: 0.0826
# Epoch 44/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0048 - mean_absolute_error: 0.0559 - val_loss: 0.0069 - val_mean_absolute_error: 0.0678
# Epoch 45/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0051 - mean_absolute_error: 0.0570 - val_loss: 0.0092 - val_mean_absolute_error: 0.0784
# Epoch 46/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0044 - mean_absolute_error: 0.0520 - val_loss: 0.0055 - val_mean_absolute_error: 0.0614
# Epoch 47/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0023 - mean_absolute_error: 0.0377 - val_loss: 0.0060 - val_mean_absolute_error: 0.0619
# Epoch 48/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0031 - mean_absolute_error: 0.0448 - val_loss: 0.0082 - val_mean_absolute_error: 0.0743
# Epoch 49/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0034 - mean_absolute_error: 0.0451 - val_loss: 0.0043 - val_mean_absolute_error: 0.0550
# Epoch 50/300
# 204/204 [==============================] - 0s 137us/sample - loss: 0.0019 - mean_absolute_error: 0.0327 - val_loss: 0.0042 - val_mean_absolute_error: 0.0527
# Epoch 51/300
# 204/204 [==============================] - 0s 137us/sample - loss: 0.0016 - mean_absolute_error: 0.0300 - val_loss: 0.0047 - val_mean_absolute_error: 0.0576
# Epoch 52/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0018 - mean_absolute_error: 0.0308 - val_loss: 0.0038 - val_mean_absolute_error: 0.0502
# Epoch 53/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0018 - mean_absolute_error: 0.0328 - val_loss: 0.0041 - val_mean_absolute_error: 0.0515
# Epoch 54/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0014 - mean_absolute_error: 0.0288 - val_loss: 0.0041 - val_mean_absolute_error: 0.0528
# Epoch 55/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0016 - mean_absolute_error: 0.0303 - val_loss: 0.0046 - val_mean_absolute_error: 0.0556
# Epoch 56/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0017 - mean_absolute_error: 0.0320 - val_loss: 0.0043 - val_mean_absolute_error: 0.0536
# Epoch 57/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0014 - mean_absolute_error: 0.0280 - val_loss: 0.0041 - val_mean_absolute_error: 0.0522
# Epoch 58/300
# 204/204 [==============================] - 0s 177us/sample - loss: 0.0013 - mean_absolute_error: 0.0267 - val_loss: 0.0039 - val_mean_absolute_error: 0.0508
# Epoch 59/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0012 - mean_absolute_error: 0.0252 - val_loss: 0.0042 - val_mean_absolute_error: 0.0526
# Epoch 60/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0018 - mean_absolute_error: 0.0332 - val_loss: 0.0060 - val_mean_absolute_error: 0.0634
# Epoch 61/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0024 - mean_absolute_error: 0.0409 - val_loss: 0.0037 - val_mean_absolute_error: 0.0500
# Epoch 62/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0013 - mean_absolute_error: 0.0282 - val_loss: 0.0046 - val_mean_absolute_error: 0.0551
# Epoch 63/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0023 - mean_absolute_error: 0.0358 - val_loss: 0.0040 - val_mean_absolute_error: 0.0520
# Epoch 64/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0016 - mean_absolute_error: 0.0293 - val_loss: 0.0037 - val_mean_absolute_error: 0.0492
# Epoch 65/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0013 - mean_absolute_error: 0.0267 - val_loss: 0.0063 - val_mean_absolute_error: 0.0639
# Epoch 66/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0025 - mean_absolute_error: 0.0393 - val_loss: 0.0043 - val_mean_absolute_error: 0.0539
# Epoch 67/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0038 - mean_absolute_error: 0.0489 - val_loss: 0.0092 - val_mean_absolute_error: 0.0819
# Epoch 68/300
# 204/204 [==============================] - 0s 255us/sample - loss: 0.0048 - mean_absolute_error: 0.0548 - val_loss: 0.0063 - val_mean_absolute_error: 0.0644
# Epoch 69/300
# 204/204 [==============================] - 0s 274us/sample - loss: 0.0036 - mean_absolute_error: 0.0481 - val_loss: 0.0057 - val_mean_absolute_error: 0.0586
# Epoch 70/300
# 204/204 [==============================] - 0s 372us/sample - loss: 0.0023 - mean_absolute_error: 0.0384 - val_loss: 0.0040 - val_mean_absolute_error: 0.0534
# Epoch 71/300
# 204/204 [==============================] - 0s 255us/sample - loss: 0.0026 - mean_absolute_error: 0.0402 - val_loss: 0.0080 - val_mean_absolute_error: 0.0752
# Epoch 72/300
# 204/204 [==============================] - 0s 647us/sample - loss: 0.0041 - mean_absolute_error: 0.0533 - val_loss: 0.0056 - val_mean_absolute_error: 0.0590
# Epoch 73/300
# 204/204 [==============================] - 0s 686us/sample - loss: 0.0023 - mean_absolute_error: 0.0382 - val_loss: 0.0048 - val_mean_absolute_error: 0.0582
# Epoch 74/300
# 204/204 [==============================] - 0s 529us/sample - loss: 0.0041 - mean_absolute_error: 0.0515 - val_loss: 0.0086 - val_mean_absolute_error: 0.0781
# Epoch 75/300
# 204/204 [==============================] - 0s 412us/sample - loss: 0.0067 - mean_absolute_error: 0.0673 - val_loss: 0.0109 - val_mean_absolute_error: 0.0844
# Epoch 76/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0058 - mean_absolute_error: 0.0588 - val_loss: 0.0049 - val_mean_absolute_error: 0.0572

# %%
# show the graph of model loss in trainig and validation 

plt.figure(figsize=(15,8))
plt.xlabel('Epoch')
plt.ylabel('Mean Square Error')
plt.plot(history.epoch, history.history['loss'],
           label='Train Loss')
plt.plot(history.epoch, history.history['val_loss'],
           label = 'Val loss')
plt.title('Model loss')
plt.legend()
plt.savefig('Figures/model_loss_0.png',dpi=1000,bbox_inches='tight')

# %%
#check the model performace in test dataset
score = model.evaluate(X_test, y_test, verbose=1)
print('loss value: ', score[0])
print('Mean absolute error: ', score[1])
# Out:
# 64/64 [==============================] - 0s 244us/sample - loss: 0.0146 - mean_absolute_error: 0.0909
# loss value:  0.014579569920897484
# Mean absolute error:  0.09090349

# %%
'''=== predict the house price ==='''

# predict house price using the test data 
test_predictions = model.predict(X_test).flatten()
print(test_predictions)
# Out:
# [ 1.8346972   0.51464444  1.5517721  -0.6407922   0.62780833  1.4557326
#   1.8673447  -1.0043442   0.3000713   0.57019335 -0.9611104   0.62448776
#  -0.82539403 -1.0916454  -0.9202698   1.466212    1.7001055   1.1892526
#   0.3277227   0.2828956  -1.1075861  -0.7204732  -1.1744978  -0.9298165
#  -0.99093246  0.9241779  -1.1292721   0.965034    0.43343383 -0.87247396
#   0.27663258 -0.79107064  1.3370199   1.8969712  -0.07383779 -1.1099466
#   2.0368962   1.0229448  -0.69219744  2.1220438   0.5244556  -0.54029727
#   1.9420427  -0.75970817 -0.67695636 -0.985477   -1.1573712  -0.7209875
#   1.4351221  -0.00347569 -1.1076932   0.28922042 -1.0249072  -1.148339
#  -1.1559237   0.62815106  0.56505984 -0.7290008  -1.2180344  -0.63912994
#   0.9978505   1.5949132  -0.37474275  0.19081548]

# %%
# show the true value and predicted value in dataframe
true_predicted = pd.DataFrame(list(zip(y_test, test_predictions)), 
                    columns=['True Value','Predicted Value'])
true_predicted.head(10)
# Out:
#               True Value  Predicted Value
# 0   [1.9962017456503172]         1.834697
# 1   [0.5514604154564543]         0.514644
# 2   [1.5825364929879715]         1.551772
# 3  [-0.7564215152247422]        -0.640792
# 4   [0.5535184515393514]         0.627808
# 5   [1.7533534878684431]         1.455733
# 6   [1.8017173358165282]         1.867345
# 7  [-1.0229371879599352]        -1.004344
# 8   [0.4742840623478076]         0.300071
# 9   [0.6625943639329053]         0.570193

# %%
#visiulize the true value with predicted value (using line graph)
x = test_predictions
y = y_test
plt.figure(figsize=(30,10))
plt.plot(x, label='predicted value')
plt.plot(y, label='true value')
plt.title('Evaluation Result')
plt.legend()
plt.savefig('Evaluation_Result_0.png',dpi=1000,bbox_inches='tight')
plt.show()

# %%
'''=== Visualize the model evaluation skill ==='''


# visualize the prediction uisng diagonal line
y = test_predictions #y-axis
x = y_test #x-axis
fig, ax = plt.subplots(figsize=(10,6)) # create figure
ax.scatter(x,y) #scatter plots for x,y
ax.set(xlim=(0,2.5), ylim=(0, 2.5)) #set limit
ax.plot(ax.get_xlim(), ax.get_ylim(), color ='red') # draw 45 degree diagonal in figure
plt.xlabel('True Values')
plt.ylabel('Predicted values')
plt.title('Evaluation Result')
plt.savefig('x_Evaluation_Result_0.png',dpi=1000,bbox_inches='tight')
plt.show()

# %% [markdown]
# ## subset_1

# %%
path = 'max_data/SixAirlinesDataV2.csv'
data_1 = pd.read_csv(path, sep = ',', na_filter = False)

data_1=data_1.drop(columns='Unnamed: 0')
data_1.head()
# Out:
#     Airline  Aircraft  FlightDuration  IsInternational  SeatsEconomy  \
# 0  0.089142 -0.693889       -0.817844         3.294215     -0.436182
# 1  0.089142 -0.693889       -0.783876         3.294215     -1.029628
# 2  0.648468 -0.693889       -1.199981        -0.303562     -0.554871
# 3  0.089142  1.441153       -1.542489         3.294215     -1.108754
# 4  1.207793 -0.693889       -0.161134        -0.303562     -0.053740
#
#    SeatsPremium  PitchEconomy  PitchPremium  WidthEconomy  WidthPremium  \
# 0     -0.343385      1.220342     -2.215259      0.302148     -1.357472
# 1     -1.147585      1.220342     -2.968588     -1.455802     -2.258698
# 2     -1.878677     -1.818641      1.551387     -1.455802      1.346207
# 3     -1.147585      1.220342     -2.968588     -1.455802     -2.258698
# 4     -0.416494      1.220342      0.044729     -1.455802     -0.456246
#
#    PriceEconomy  PricePremium  PriceRelative  SeatsTotal  PitchDifference  \
# 0     -0.578401     -0.802415           0.06   -0.442612        -2.091811
# 1     -0.667926     -0.870953           0.07   -1.098823        -2.650559
# 2     -1.010589     -1.018270           0.65   -0.794154         1.819422
# 3     -1.141274     -1.256183           0.09   -1.169131        -2.650559
# 4      1.630900      1.014233           0.07   -0.114507        -0.415569
#
#    WidthDifference  PercentPremiumSeats  month_num
# 0        -1.381970             0.009871  -1.639972
# 1        -1.381970            -0.411592  -1.639972
# 2         1.912112            -2.053194   0.282340
# 3        -1.381970            -0.297797   0.282340
# 4         0.265071            -0.457953  -0.678816

# %%
# variables seleccionadas según diferentes criterios  根据不同标准选择变量
Y = data_1[['PriceEconomy']].copy()
Y = Y.values
x_data_1 = [10,7,13,14,15]

data_1.drop(data_1.columns[x_data_1], axis=1, inplace=True)
X_1 = data_1.values

# %%
data_1.head()
# Out:
#     Airline  Aircraft  FlightDuration  IsInternational  SeatsEconomy  \
# 0  0.089142 -0.693889       -0.817844         3.294215     -0.436182
# 1  0.089142 -0.693889       -0.783876         3.294215     -1.029628
# 2  0.648468 -0.693889       -1.199981        -0.303562     -0.554871
# 3  0.089142  1.441153       -1.542489         3.294215     -1.108754
# 4  1.207793 -0.693889       -0.161134        -0.303562     -0.053740
#
#    SeatsPremium  PitchEconomy  WidthEconomy  WidthPremium  PricePremium  \
# 0     -0.343385      1.220342      0.302148     -1.357472     -0.802415
# 1     -1.147585      1.220342     -1.455802     -2.258698     -0.870953
# 2     -1.878677     -1.818641     -1.455802      1.346207     -1.018270
# 3     -1.147585      1.220342     -1.455802     -2.258698     -1.256183
# 4     -0.416494      1.220342     -1.455802     -0.456246      1.014233
#
#    PriceRelative  PercentPremiumSeats  month_num
# 0           0.06             0.009871  -1.639972
# 1           0.07            -0.411592  -1.639972
# 2           0.65            -2.053194   0.282340
# 3           0.09            -0.297797   0.282340
# 4           0.07            -0.457953  -0.678816

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale_1 = min_max_scaler.fit_transform(X_1)

# %%
# shuffle and split data into train (~80%) and test (~20%)
X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(X_scale_1, Y, 
                                                    test_size=0.2, random_state=42) 

print('training data shape: ',X_train_1.shape)
print('testing data shape: ',X_test_1.shape)
# Out:
# training data shape:  (256, 13)
# testing data shape:  (64, 13)

# %%
#get number of columns in training data
n_cols_1 = X_train_1.shape[1]

# builds model
model_1 = keras.Sequential()

model_1.add(keras.layers.Dense(150, activation=tf.nn.relu, 
                       input_shape=(n_cols_1,)))
model_1.add(keras.layers.Dense(150, activation=tf.nn.relu))
model_1.add(keras.layers.Dense(150, activation=tf.nn.relu))
model_1.add(keras.layers.Dense(150, activation=tf.nn.relu))
model_1.add(keras.layers.Dense(150, activation=tf.nn.relu))
model_1.add(keras.layers.Dense(1))

#compile model
model_1.compile(loss='mse', optimizer='adam', metrics=['mae']) # use metric as mean absolute error

#inspect the model
model_1.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 150)               2100
# _________________________________________________________________
# dense_31 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_32 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_33 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_34 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 92,851
# Trainable params: 92,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train model and perform validation test

early_stop_1 = EarlyStopping(monitor='val_loss', patience=15) # stops training when it doesn't show improvemnet.

history_1 = model_1.fit(X_train_1, y_train_1, epochs=300, 
          validation_split=0.2, verbose=1, callbacks=[early_stop_1])
# Out:
# Train on 204 samples, validate on 52 samples
# Epoch 1/300
# 204/204 [==============================] - 0s 2ms/sample - loss: 0.8870 - mean_absolute_error: 0.7971 - val_loss: 0.6891 - val_mean_absolute_error: 0.6867
# Epoch 2/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.5793 - mean_absolute_error: 0.6164 - val_loss: 0.3717 - val_mean_absolute_error: 0.4832
# Epoch 3/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.2933 - mean_absolute_error: 0.4130 - val_loss: 0.1974 - val_mean_absolute_error: 0.3257
# Epoch 4/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.1346 - mean_absolute_error: 0.2800 - val_loss: 0.2468 - val_mean_absolute_error: 0.4161
# Epoch 5/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.1342 - mean_absolute_error: 0.2722 - val_loss: 0.1196 - val_mean_absolute_error: 0.2446
# Epoch 6/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0650 - mean_absolute_error: 0.1940 - val_loss: 0.0607 - val_mean_absolute_error: 0.1880
# Epoch 7/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0424 - mean_absolute_error: 0.1499 - val_loss: 0.0450 - val_mean_absolute_error: 0.1593
# Epoch 8/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0363 - mean_absolute_error: 0.1387 - val_loss: 0.0470 - val_mean_absolute_error: 0.1462
# Epoch 9/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0315 - mean_absolute_error: 0.1351 - val_loss: 0.0400 - val_mean_absolute_error: 0.1368
# Epoch 10/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0278 - mean_absolute_error: 0.1300 - val_loss: 0.0432 - val_mean_absolute_error: 0.1553
# Epoch 11/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0277 - mean_absolute_error: 0.1292 - val_loss: 0.0300 - val_mean_absolute_error: 0.1240
# Epoch 12/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0184 - mean_absolute_error: 0.1032 - val_loss: 0.0246 - val_mean_absolute_error: 0.1287
# Epoch 13/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0167 - mean_absolute_error: 0.1042 - val_loss: 0.0169 - val_mean_absolute_error: 0.0998
# Epoch 14/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0122 - mean_absolute_error: 0.0873 - val_loss: 0.0152 - val_mean_absolute_error: 0.0926
# Epoch 15/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0108 - mean_absolute_error: 0.0823 - val_loss: 0.0128 - val_mean_absolute_error: 0.0883
# Epoch 16/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0082 - mean_absolute_error: 0.0705 - val_loss: 0.0117 - val_mean_absolute_error: 0.0867
# Epoch 17/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0089 - mean_absolute_error: 0.0733 - val_loss: 0.0168 - val_mean_absolute_error: 0.0998
# Epoch 18/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0085 - mean_absolute_error: 0.0748 - val_loss: 0.0116 - val_mean_absolute_error: 0.0869
# Epoch 19/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0059 - mean_absolute_error: 0.0594 - val_loss: 0.0096 - val_mean_absolute_error: 0.0759
# Epoch 20/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0057 - mean_absolute_error: 0.0600 - val_loss: 0.0104 - val_mean_absolute_error: 0.0831
# Epoch 21/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.0087 - mean_absolute_error: 0.0745 - val_loss: 0.0157 - val_mean_absolute_error: 0.1016
# Epoch 22/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0096 - mean_absolute_error: 0.0801 - val_loss: 0.0091 - val_mean_absolute_error: 0.0761
# Epoch 23/300
# 204/204 [==============================] - 0s 169us/sample - loss: 0.0086 - mean_absolute_error: 0.0732 - val_loss: 0.0065 - val_mean_absolute_error: 0.0625
# Epoch 24/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0072 - mean_absolute_error: 0.0672 - val_loss: 0.0086 - val_mean_absolute_error: 0.0725
# Epoch 25/300
# 204/204 [==============================] - 0s 294us/sample - loss: 0.0043 - mean_absolute_error: 0.0499 - val_loss: 0.0060 - val_mean_absolute_error: 0.0648
# Epoch 26/300
# 204/204 [==============================] - 0s 235us/sample - loss: 0.0045 - mean_absolute_error: 0.0529 - val_loss: 0.0126 - val_mean_absolute_error: 0.0844
# Epoch 27/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0048 - mean_absolute_error: 0.0551 - val_loss: 0.0060 - val_mean_absolute_error: 0.0617
# Epoch 28/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0036 - mean_absolute_error: 0.0475 - val_loss: 0.0058 - val_mean_absolute_error: 0.0602
# Epoch 29/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0034 - mean_absolute_error: 0.0464 - val_loss: 0.0064 - val_mean_absolute_error: 0.0631
# Epoch 30/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0034 - mean_absolute_error: 0.0466 - val_loss: 0.0062 - val_mean_absolute_error: 0.0624
# Epoch 31/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0026 - mean_absolute_error: 0.0404 - val_loss: 0.0045 - val_mean_absolute_error: 0.0536
# Epoch 32/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0035 - mean_absolute_error: 0.0460 - val_loss: 0.0044 - val_mean_absolute_error: 0.0533
# Epoch 33/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0029 - mean_absolute_error: 0.0416 - val_loss: 0.0055 - val_mean_absolute_error: 0.0591
# Epoch 34/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0026 - mean_absolute_error: 0.0425 - val_loss: 0.0051 - val_mean_absolute_error: 0.0582
# Epoch 35/300
# 204/204 [==============================] - 0s 255us/sample - loss: 0.0019 - mean_absolute_error: 0.0329 - val_loss: 0.0046 - val_mean_absolute_error: 0.0530
# Epoch 36/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0023 - mean_absolute_error: 0.0362 - val_loss: 0.0044 - val_mean_absolute_error: 0.0523
# Epoch 37/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0020 - mean_absolute_error: 0.0335 - val_loss: 0.0064 - val_mean_absolute_error: 0.0645
# Epoch 38/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0035 - mean_absolute_error: 0.0469 - val_loss: 0.0046 - val_mean_absolute_error: 0.0524
# Epoch 39/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0034 - mean_absolute_error: 0.0464 - val_loss: 0.0072 - val_mean_absolute_error: 0.0687
# Epoch 40/300
# 204/204 [==============================] - 0s 274us/sample - loss: 0.0050 - mean_absolute_error: 0.0581 - val_loss: 0.0069 - val_mean_absolute_error: 0.0666
# Epoch 41/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0062 - mean_absolute_error: 0.0642 - val_loss: 0.0125 - val_mean_absolute_error: 0.0891
# Epoch 42/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0060 - mean_absolute_error: 0.0626 - val_loss: 0.0118 - val_mean_absolute_error: 0.0936
# Epoch 43/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0114 - mean_absolute_error: 0.0871 - val_loss: 0.0064 - val_mean_absolute_error: 0.0596
# Epoch 44/300
# 204/204 [==============================] - 0s 333us/sample - loss: 0.0071 - mean_absolute_error: 0.0642 - val_loss: 0.0111 - val_mean_absolute_error: 0.0912
# Epoch 45/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0071 - mean_absolute_error: 0.0668 - val_loss: 0.0110 - val_mean_absolute_error: 0.0830
# Epoch 46/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0077 - mean_absolute_error: 0.0719 - val_loss: 0.0072 - val_mean_absolute_error: 0.0684
# Epoch 47/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0076 - mean_absolute_error: 0.0680 - val_loss: 0.0077 - val_mean_absolute_error: 0.0668
# Epoch 48/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0065 - mean_absolute_error: 0.0630 - val_loss: 0.0103 - val_mean_absolute_error: 0.0796
# Epoch 49/300
# 204/204 [==============================] - 0s 255us/sample - loss: 0.0054 - mean_absolute_error: 0.0589 - val_loss: 0.0086 - val_mean_absolute_error: 0.0756
# Epoch 50/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.
-04 - mean_absolute_error: 0.0121 - val_loss: 0.0025 - val_mean_absolute_error: 0.0390
# Epoch 112/300
# 204/204 [==============================] - 0s 139us/sample - loss: 3.0030e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0025 - val_mean_absolute_error: 0.0396
# Epoch 113/300
# 204/204 [==============================] - 0s 208us/sample - loss: 2.7425e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0029 - val_mean_absolute_error: 0.0412
# Epoch 114/300
# 204/204 [==============================] - 0s 66us/sample - loss: 3.0830e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0033 - val_mean_absolute_error: 0.0439
# Epoch 115/300
# 204/204 [==============================] - 0s 178us/sample - loss: 6.2306e-04 - mean_absolute_error: 0.0204 - val_loss: 0.0027 - val_mean_absolute_error: 0.0392
# Epoch 116/300
# 204/204 [==============================] - 0s 216us/sample - loss: 4.8310e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0024 - val_mean_absolute_error: 0.0405
# Epoch 117/300
# 204/204 [==============================] - 0s 216us/sample - loss: 4.0831e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0030 - val_mean_absolute_error: 0.0421
# Epoch 118/300
# 204/204 [==============================] - 0s 157us/sample - loss: 6.5825e-04 - mean_absolute_error: 0.0199 - val_loss: 0.0030 - val_mean_absolute_error: 0.0417
# Epoch 119/300
# 204/204 [==============================] - 0s 157us/sample - loss: 5.3211e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0026 - val_mean_absolute_error: 0.0397
# Epoch 120/300
# 204/204 [==============================] - 0s 137us/sample - loss: 3.1326e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0026 - val_mean_absolute_error: 0.0398
# Epoch 121/300
# 204/204 [==============================] - 0s 176us/sample - loss: 2.7096e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0027 - val_mean_absolute_error: 0.0407

# %%
# show the graph of model loss in trainig and validation 

plt.figure(figsize=(15,8))
plt.xlabel('Epoch')
plt.ylabel('Mean Square Error')
plt.plot(history_1.epoch, history_1.history['loss'],
           label='Train Loss')
plt.plot(history_1.epoch, history_1.history['val_loss'],
           label = 'Val loss')
plt.title('Model loss')
plt.legend()
plt.savefig('Figures/model_loss_1.png',dpi=1000,bbox_inches='tight')

# %%
#check the model performace in test dataset
score_1 = model_1.evaluate(X_test_1, y_test_1, verbose=1)
print('loss value: ', score_1[0])
print('Mean absolute error: ', score_1[1])
# Out:
# 64/64 [==============================] - 0s 62us/sample - loss: 0.0078 - mean_absolute_error: 0.0630
# loss value:  0.007758594583719969
# Mean absolute error:  0.06295981

# %%
'''=== predict the house price ==='''

# predict house price using the test data 
test_predictions_1 = model_1.predict(X_test_1).flatten()
print(test_predictions_1)
# Out:
# [ 1.890025    0.5377958   1.5940715  -0.6570532   0.6082451   1.492052
#   1.8922848  -0.98752594  0.45243925  0.6036373  -1.0324078   0.7111884
#  -0.87350845 -1.0905347  -0.9096359   1.486723    1.8178751   1.2676799
#   0.48132858  0.30670238 -1.0937295  -0.87471515 -1.1773281  -0.96856874
#  -0.9771159   1.1927938  -1.1123881   0.998715    0.5443909  -0.9682822
#   0.31588885 -0.7945725   1.4243038   1.9842227  -0.05788366 -1.0729765
#   2.2344165   1.0757254  -0.6448309   2.2078538   0.4928555  -0.3729738
#   1.9593241  -0.7686906  -0.7044572  -1.0270256  -1.2067482  -0.7363243
#   1.4544203   0.1129306  -1.111373    0.39885545 -1.0210145  -1.2012519
#  -1.1561506   0.68317115  0.5688523  -0.710803   -1.2492653  -0.60223264
#   1.0439126   1.636954   -0.22758758  0.03602075]

# %%
# show the true value and predicted value in dataframe
true_predicted_1 = pd.DataFrame(list(zip(y_test_1, test_predictions_1)), 
                    columns=['True Value','Predicted Value'])
true_predicted_1.head(10)
# Out:
#               True Value  Predicted Value
# 0   [1.9962017456503172]         1.890025
# 1   [0.5514604154564543]         0.537796
# 2   [1.5825364929879715]         1.594072
# 3  [-0.7564215152247422]        -0.657053
# 4   [0.5535184515393514]         0.608245
# 5   [1.7533534878684431]         1.492052
# 6   [1.8017173358165282]         1.892285
# 7  [-1.0229371879599352]        -0.987526
# 8   [0.4742840623478076]         0.452439
# 9   [0.6625943639329053]         0.603637

# %%
#visiulize the true value with predicted value (using line graph)
x_1 = test_predictions_1
y_1 = y_test_1
plt.figure(figsize=(30,10))
plt.plot(x_1, label='predicted value')
plt.plot(y_1, label='true value')
plt.title('Evaluation Result')
plt.legend()
plt.savefig('Evaluation_Result_1.png',dpi=1000,bbox_inches='tight')
plt.show()

# %%
'''=== Visualize the model evaluation skill ==='''


# visualize the prediction uisng diagonal line
y_1 = test_predictions_1 #y-axis
x_1 = y_test_1 #x-axis
fig, ax = plt.subplots(figsize=(10,6)) # create figure
ax.scatter(x_1,y_1) #scatter plots for x,y
ax.set(xlim=(0,2.5), ylim=(0, 2.5)) #set limit
ax.plot(ax.get_xlim(), ax.get_ylim(), color ='red') # draw 45 degree diagonal in figure
plt.xlabel('True Values')
plt.ylabel('Predicted values')
plt.title('Evaluation Result')
plt.savefig('x_Evaluation_Result_1.png',dpi=1000,bbox_inches='tight')
plt.show()

# %% [markdown]
# ## subset_2

# %%
path = 'max_data/SixAirlinesDataV2.csv'
data_2 = pd.read_csv(path, sep = ',', na_filter = False)

data_2=data_2.drop(columns='Unnamed: 0')
data_2.head()
# Out:
#     Airline  Aircraft  FlightDuration  IsInternational  SeatsEconomy  \
# 0  0.089142 -0.693889       -0.817844         3.294215     -0.436182
# 1  0.089142 -0.693889       -0.783876         3.294215     -1.029628
# 2  0.648468 -0.693889       -1.199981        -0.303562     -0.554871
# 3  0.089142  1.441153       -1.542489         3.294215     -1.108754
# 4  1.207793 -0.693889       -0.161134        -0.303562     -0.053740
#
#    SeatsPremium  PitchEconomy  PitchPremium  WidthEconomy  WidthPremium  \
# 0     -0.343385      1.220342     -2.215259      0.302148     -1.357472
# 1     -1.147585      1.220342     -2.968588     -1.455802     -2.258698
# 2     -1.878677     -1.818641      1.551387     -1.455802      1.346207
# 3     -1.147585      1.220342     -2.968588     -1.455802     -2.258698
# 4     -0.416494      1.220342      0.044729     -1.455802     -0.456246
#
#    PriceEconomy  PricePremium  PriceRelative  SeatsTotal  PitchDifference  \
# 0     -0.578401     -0.802415           0.06   -0.442612        -2.091811
# 1     -0.667926     -0.870953           0.07   -1.098823        -2.650559
# 2     -1.010589     -1.018270           0.65   -0.794154         1.819422
# 3     -1.141274     -1.256183           0.09   -1.169131        -2.650559
# 4      1.630900      1.014233           0.07   -0.114507        -0.415569
#
#    WidthDifference  PercentPremiumSeats  month_num
# 0        -1.381970             0.009871  -1.639972
# 1        -1.381970            -0.411592  -1.639972
# 2         1.912112            -2.053194   0.282340
# 3        -1.381970            -0.297797   0.282340
# 4         0.265071            -0.457953  -0.678816

# %%
# variables seleccionadas según diferentes criterios  根据不同标准选择变量
Y = data_2[['PriceEconomy']].copy()
Y = Y.values
x_data_2 = [10,7,13,14,15,17]

data_2.drop(data_2.columns[x_data_2], axis=1, inplace=True)
X_2 = data_2.values

# %%
data_2.head()
# Out:
#     Airline  Aircraft  FlightDuration  IsInternational  SeatsEconomy  \
# 0  0.089142 -0.693889       -0.817844         3.294215     -0.436182
# 1  0.089142 -0.693889       -0.783876         3.294215     -1.029628
# 2  0.648468 -0.693889       -1.199981        -0.303562     -0.554871
# 3  0.089142  1.441153       -1.542489         3.294215     -1.108754
# 4  1.207793 -0.693889       -0.161134        -0.303562     -0.053740
#
#    SeatsPremium  PitchEconomy  WidthEconomy  WidthPremium  PricePremium  \
# 0     -0.343385      1.220342      0.302148     -1.357472     -0.802415
# 1     -1.147585      1.220342     -1.455802     -2.258698     -0.870953
# 2     -1.878677     -1.818641     -1.455802      1.346207     -1.018270
# 3     -1.147585      1.220342     -1.455802     -2.258698     -1.256183
# 4     -0.416494      1.220342     -1.455802     -0.456246      1.014233
#
#    PriceRelative  PercentPremiumSeats
# 0           0.06             0.009871
# 1           0.07            -0.411592
# 2           0.65            -2.053194
# 3           0.09            -0.297797
# 4           0.07            -0.457953

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale_2 = min_max_scaler.fit_transform(X_2)

# %%
# shuffle and split data into train (~80%) and test (~20%)
X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X_scale_2, Y, 
                                                    test_size=0.2, random_state=42) 

print('training data shape: ',X_train_2.shape)
print('testing data shape: ',X_test_2.shape)
# Out:
# training data shape:  (256, 12)
# testing data shape:  (64, 12)

# %%
#get number of columns in training data
n_cols_2 = X_train_2.shape[1]

# builds model
model_2 = keras.Sequential()

model_2.add(keras.layers.Dense(150, activation=tf.nn.relu, 
                       input_shape=(n_cols_2,)))
model_2.add(keras.layers.Dense(150, activation=tf.nn.relu))
model_2.add(keras.layers.Dense(150, activation=tf.nn.relu))
model_2.add(keras.layers.Dense(150, activation=tf.nn.relu))
model_2.add(keras.layers.Dense(150, activation=tf.nn.relu))
model_2.add(keras.layers.Dense(1))

#compile model
model_2.compile(loss='mse', optimizer='adam', metrics=['mae']) # use metric as mean absolute error

#inspect the model
model_2.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_36 (Dense)             (None, 150)               1950
# _________________________________________________________________
# dense_37 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_38 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_39 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_40 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_41 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 92,701
# Trainable params: 92,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train model and perform validation test

early_stop_2 = EarlyStopping(monitor='val_loss', patience=15) # stops training when it doesn't show improvemnet.

history_2 = model_2.fit(X_train_2, y_train_2, epochs=300, 
          validation_split=0.2, verbose=1, callbacks=[early_stop_2])
# Out:
# Train on 204 samples, validate on 52 samples
# Epoch 1/300
# 204/204 [==============================] - 0s 2ms/sample - loss: 0.8844 - mean_absolute_error: 0.7931 - val_loss: 0.6641 - val_mean_absolute_error: 0.6723
# Epoch 2/300
# 204/204 [==============================] - 0s 204us/sample - loss: 0.5529 - mean_absolute_error: 0.6095 - val_loss: 0.2399 - val_mean_absolute_error: 0.3733
# Epoch 3/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.1704 - mean_absolute_error: 0.3108 - val_loss: 0.0912 - val_mean_absolute_error: 0.2328
# Epoch 4/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0732 - mean_absolute_error: 0.2058 - val_loss: 0.0557 - val_mean_absolute_error: 0.1872
# Epoch 5/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0522 - mean_absolute_error: 0.1825 - val_loss: 0.0385 - val_mean_absolute_error: 0.1551
# Epoch 6/300
# 204/204 [==============================] - 0s 255us/sample - loss: 0.0264 - mean_absolute_error: 0.1213 - val_loss: 0.0233 - val_mean_absolute_error: 0.1151
# Epoch 7/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0188 - mean_absolute_error: 0.1019 - val_loss: 0.0196 - val_mean_absolute_error: 0.1131
# Epoch 8/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0172 - mean_absolute_error: 0.1005 - val_loss: 0.0119 - val_mean_absolute_error: 0.0847
# Epoch 9/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0138 - mean_absolute_error: 0.0926 - val_loss: 0.0114 - val_mean_absolute_error: 0.0810
# Epoch 10/300
# 204/204 [==============================] - 0s 137us/sample - loss: 0.0119 - mean_absolute_error: 0.0855 - val_loss: 0.0090 - val_mean_absolute_error: 0.0765
# Epoch 11/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0091 - mean_absolute_error: 0.0730 - val_loss: 0.0058 - val_mean_absolute_error: 0.0581
# Epoch 12/300
# 204/204 [==============================] - 0s 137us/sample - loss: 0.0076 - mean_absolute_error: 0.0669 - val_loss: 0.0060 - val_mean_absolute_error: 0.0619
# Epoch 13/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0090 - mean_absolute_error: 0.0762 - val_loss: 0.0076 - val_mean_absolute_error: 0.0701
# Epoch 14/300
# 204/204 [==============================] - 0s 137us/sample - loss: 0.0084 - mean_absolute_error: 0.0734 - val_loss: 0.0075 - val_mean_absolute_error: 0.0677
# Epoch 15/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0084 - mean_absolute_error: 0.0699 - val_loss: 0.0051 - val_mean_absolute_error: 0.0526
# Epoch 16/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0051 - mean_absolute_error: 0.0527 - val_loss: 0.0064 - val_mean_absolute_error: 0.0603
# Epoch 17/300
# 204/204 [==============================] - 0s 255us/sample - loss: 0.0054 - mean_absolute_error: 0.0588 - val_loss: 0.0045 - val_mean_absolute_error: 0.0521
# Epoch 18/300
# 204/204 [==============================] - 0s 235us/sample - loss: 0.0058 - mean_absolute_error: 0.0572 - val_loss: 0.0038 - val_mean_absolute_error: 0.0440
# Epoch 19/300
# 204/204 [==============================] - 0s 235us/sample - loss: 0.0044 - mean_absolute_error: 0.0516 - val_loss: 0.0052 - val_mean_absolute_error: 0.0567
# Epoch 20/300
# 204/204 [==============================] - 0s 236us/sample - loss: 0.0055 - mean_absolute_error: 0.0567 - val_loss: 0.0035 - val_mean_absolute_error: 0.0435
# Epoch 21/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0050 - mean_absolute_error: 0.0521 - val_loss: 0.0095 - val_mean_absolute_error: 0.0796
# Epoch 22/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0085 - mean_absolute_error: 0.0721 - val_loss: 0.0050 - val_mean_absolute_error: 0.0531
# Epoch 23/300
# 204/204 [==============================] - 0s 235us/sample - loss: 0.0073 - mean_absolute_error: 0.0669 - val_loss: 0.0056 - val_mean_absolute_error: 0.0575
# Epoch 24/300
# 204/204 [==============================] - 0s 333us/sample - loss: 0.0058 - mean_absolute_error: 0.0603 - val_loss: 0.0049 - val_mean_absolute_error: 0.0560
# Epoch 25/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0059 - mean_absolute_error: 0.0606 - val_loss: 0.0055 - val_mean_absolute_error: 0.0580
# Epoch 26/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0047 - mean_absolute_error: 0.0515 - val_loss: 0.0061 - val_mean_absolute_error: 0.0635
# Epoch 27/300
# 204/204 [==============================] - 0s 137us/sample - loss: 0.0045 - mean_absolute_error: 0.0506 - val_loss: 0.0030 - val_mean_absolute_error: 0.0417
# Epoch 28/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0031 - mean_absolute_error: 0.0427 - val_loss: 0.0100 - val_mean_absolute_error: 0.0795
# Epoch 29/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0045 - mean_absolute_error: 0.0513 - val_loss: 0.0033 - val_mean_absolute_error: 0.0421
# Epoch 30/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0028 - mean_absolute_error: 0.0386 - val_loss: 0.0025 - val_mean_absolute_error: 0.0364
# Epoch 31/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0031 - mean_absolute_error: 0.0418 - val_loss: 0.0036 - val_mean_absolute_error: 0.0477
# Epoch 32/300
# 204/204 [==============================] - 0s 137us/sample - loss: 0.0025 - mean_absolute_error: 0.0377 - val_loss: 0.0027 - val_mean_absolute_error: 0.0395
# Epoch 33/300
# 204/204 [==============================] - 0s 137us/sample - loss: 0.0029 - mean_absolute_error: 0.0405 - val_loss: 0.0031 - val_mean_absolute_error: 0.0452
# Epoch 34/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0031 - mean_absolute_error: 0.0407 - val_loss: 0.0034 - val_mean_absolute_error: 0.0454
# Epoch 35/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0025 - mean_absolute_error: 0.0386 - val_loss: 0.0022 - val_mean_absolute_error: 0.0362
# Epoch 36/300
# 204/204 [==============================] - 0s 137us/sample - loss: 0.0020 - mean_absolute_error: 0.0358 - val_loss: 0.0026 - val_mean_absolute_error: 0.0351
# Epoch 37/300
# 204/204 [==============================] - 0s 161us/sample - loss: 0.0016 - mean_absolute_error: 0.0301 - val_loss: 0.0025 - val_mean_absolute_error: 0.0377
# Epoch 38/300
# 204/204 [==============================] - 0s 137us/sample - loss: 0.0018 - mean_absolute_error: 0.0321 - val_loss: 0.0031 - val_mean_absolute_error: 0.0411
# Epoch 39/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0017 - mean_absolute_error: 0.0295 - val_loss: 0.0023 - val_mean_absolute_error: 0.0357
# Epoch 40/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0028 - mean_absolute_error: 0.0406 - val_loss: 0.0106 - val_mean_absolute_error: 0.0893
# Epoch 41/300
# 204/204 [==============================] - 0s 316us/sample - loss: 0.0058 - mean_absolute_error: 0.0637 - val_loss: 0.0023 - val_mean_absolute_error: 0.0383
# Epoch 42/300
# 204/204 [==============================] - 0s 175us/sample - loss: 0.0046 - mean_absolute_error: 0.0544 - val_loss: 0.0100 - val_mean_absolute_error: 0.0899
# Epoch 43/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.
300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0016 - mean_absolute_error: 0.0311 - val_loss: 0.0015 - val_mean_absolute_error: 0.0273
# Epoch 63/300
# 204/204 [==============================] - 0s 157us/sample - loss: 7.2283e-04 - mean_absolute_error: 0.0210 - val_loss: 0.0014 - val_mean_absolute_error: 0.0261
# Epoch 64/300
# 204/204 [==============================] - 0s 157us/sample - loss: 8.8505e-04 - mean_absolute_error: 0.0230 - val_loss: 0.0017 - val_mean_absolute_error: 0.0283
# Epoch 65/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0014 - mean_absolute_error: 0.0288 - val_loss: 0.0016 - val_mean_absolute_error: 0.0305
# Epoch 66/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0019 - mean_absolute_error: 0.0342 - val_loss: 0.0033 - val_mean_absolute_error: 0.0448
# Epoch 67/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0018 - mean_absolute_error: 0.0332 - val_loss: 0.0023 - val_mean_absolute_error: 0.0395
# Epoch 68/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0012 - mean_absolute_error: 0.0263 - val_loss: 0.0038 - val_mean_absolute_error: 0.0429
# Epoch 69/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0015 - mean_absolute_error: 0.0304 - val_loss: 0.0024 - val_mean_absolute_error: 0.0393
# Epoch 70/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0017 - mean_absolute_error: 0.0318 - val_loss: 0.0051 - val_mean_absolute_error: 0.0623
# Epoch 71/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0026 - mean_absolute_error: 0.0415 - val_loss: 0.0028 - val_mean_absolute_error: 0.0393
# Epoch 72/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0014 - mean_absolute_error: 0.0276 - val_loss: 0.0018 - val_mean_absolute_error: 0.0328
# Epoch 73/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0011 - mean_absolute_error: 0.0246 - val_loss: 0.0021 - val_mean_absolute_error: 0.0310
# Epoch 74/300
# 204/204 [==============================] - 0s 157us/sample - loss: 9.5779e-04 - mean_absolute_error: 0.0232 - val_loss: 0.0024 - val_mean_absolute_error: 0.0342

# %%
# show the graph of model loss in trainig and validation 

plt.figure(figsize=(15,8))
plt.xlabel('Epoch')
plt.ylabel('Mean Square Error')
plt.plot(history_2.epoch, history_2.history['loss'],
           label='Train Loss')
plt.plot(history_2.epoch, history_2.history['val_loss'],
           label = 'Val loss')
plt.title('Model loss')
plt.legend()
plt.savefig('Figures/model_loss_2.png',dpi=1000,bbox_inches='tight')

# %%
#check the model performace in test dataset
score_2 = model_2.evaluate(X_test_2, y_test_2, verbose=1)
print('loss value: ', score_2[0])
print('Mean absolute error: ', score_2[1])
# Out:
# 64/64 [==============================] - 0s 63us/sample - loss: 0.0053 - mean_absolute_error: 0.0474
# loss value:  0.005253160372376442
# Mean absolute error:  0.047431823

# %%
'''=== predict the house price ==='''

# predict house price using the test data 
test_predictions_2 = model_2.predict(X_test_2).flatten()
print(test_predictions_2)
# Out:
# [ 2.032602    0.5579882   1.633004   -0.72207326  0.59076834  1.7473923
#   1.8924559  -0.9912859   0.49068147  0.61133164 -0.98457247  0.75585747
#  -0.8748252  -1.1194432  -0.8024401   1.4961623   1.8192158   1.215977
#   0.49068147  0.28587747 -1.0874908  -0.76824355 -1.137345   -0.8191039
#  -0.9369223   1.1128035  -1.098125    1.1366471   0.5643901  -0.9563519
#   0.33473185 -0.78312635  1.4993945   1.9988518  -0.04359563 -1.0615699
#   2.2818515   1.1366471  -0.6891926   2.2266724   0.50629884 -0.45980582
#   2.0280058  -0.8024401  -0.67207867 -0.9625811  -1.1785305  -0.6891926
#   1.4522526   0.09798509 -1.1137357   0.3772457  -0.9478314  -1.1344779
#  -1.1220988   0.6662861   0.54381996 -0.7092515  -1.2250503  -0.5509997
#   1.1366471   1.7436388  -0.17506488 -0.039542  ]

# %%
# show the true value and predicted value in dataframe
true_predicted_2 = pd.DataFrame(list(zip(y_test_2, test_predictions_2)), 
                    columns=['True Value','Predicted Value'])
true_predicted_2.head(10)
# Out:
#               True Value  Predicted Value
# 0   [1.9962017456503172]         2.032602
# 1   [0.5514604154564543]         0.557988
# 2   [1.5825364929879715]         1.633004
# 3  [-0.7564215152247422]        -0.722073
# 4   [0.5535184515393514]         0.590768
# 5   [1.7533534878684431]         1.747392
# 6   [1.8017173358165282]         1.892456
# 7  [-1.0229371879599352]        -0.991286
# 8   [0.4742840623478076]         0.490681
# 9   [0.6625943639329053]         0.611332

# %%
#visiulize the true value with predicted value (using line graph)
x_2 = test_predictions_2
y_2 = y_test_2
plt.figure(figsize=(30,10))
plt.plot(x_2, label='predicted value')
plt.plot(y_2, label='true value')
plt.title('Evaluation Result')
plt.legend()
plt.savefig('Evaluation_Result_2.png',dpi=1000,bbox_inches='tight')
plt.show()

# %%
'''=== Visualize the model evaluation skill ==='''


# visualize the prediction uisng diagonal line
y_2 = test_predictions_2 #y-axis
x_2 = y_test_2 #x-axis
fig, ax = plt.subplots(figsize=(10,6)) # create figure
ax.scatter(x_2,y_2) #scatter plots for x,y
ax.set(xlim=(0,2.5), ylim=(0, 2.5)) #set limit
ax.plot(ax.get_xlim(), ax.get_ylim(), color ='red') # draw 45 degree diagonal in figure
plt.xlabel('True Values')
plt.ylabel('Predicted values')
plt.title('Evaluation Result')
plt.savefig('x_Evaluation_Result_2.png',dpi=1000,bbox_inches='tight')
plt.show()

# %% [markdown]
# ## subset_3

# %%
path = 'max_data/SixAirlinesDataV2.csv'
data_3 = pd.read_csv(path, sep = ',', na_filter = False)

data_3=data_3.drop(columns='Unnamed: 0')
data_3.head()
# Out:
#     Airline  Aircraft  FlightDuration  IsInternational  SeatsEconomy  \
# 0  0.089142 -0.693889       -0.817844         3.294215     -0.436182
# 1  0.089142 -0.693889       -0.783876         3.294215     -1.029628
# 2  0.648468 -0.693889       -1.199981        -0.303562     -0.554871
# 3  0.089142  1.441153       -1.542489         3.294215     -1.108754
# 4  1.207793 -0.693889       -0.161134        -0.303562     -0.053740
#
#    SeatsPremium  PitchEconomy  PitchPremium  WidthEconomy  WidthPremium  \
# 0     -0.343385      1.220342     -2.215259      0.302148     -1.357472
# 1     -1.147585      1.220342     -2.968588     -1.455802     -2.258698
# 2     -1.878677     -1.818641      1.551387     -1.455802      1.346207
# 3     -1.147585      1.220342     -2.968588     -1.455802     -2.258698
# 4     -0.416494      1.220342      0.044729     -1.455802     -0.456246
#
#    PriceEconomy  PricePremium  PriceRelative  SeatsTotal  PitchDifference  \
# 0     -0.578401     -0.802415           0.06   -0.442612        -2.091811
# 1     -0.667926     -0.870953           0.07   -1.098823        -2.650559
# 2     -1.010589     -1.018270           0.65   -0.794154         1.819422
# 3     -1.141274     -1.256183           0.09   -1.169131        -2.650559
# 4      1.630900      1.014233           0.07   -0.114507        -0.415569
#
#    WidthDifference  PercentPremiumSeats  month_num
# 0        -1.381970             0.009871  -1.639972
# 1        -1.381970            -0.411592  -1.639972
# 2         1.912112            -2.053194   0.282340
# 3        -1.381970            -0.297797   0.282340
# 4         0.265071            -0.457953  -0.678816

# %%
# variables seleccionadas según diferentes criterios  根据不同标准选择变量
Y = data_3[['PriceEconomy']].copy()
Y = Y.values

x_data_3 = [10,7,15,13,14,17,0,1,8,9,16]

data_3.drop(data_3.columns[x_data_3], axis=1, inplace=True)
X_3 = data_3.values

# %%
data_3.head()
# Out:
#    FlightDuration  IsInternational  SeatsEconomy  SeatsPremium  PitchEconomy  \
# 0       -0.817844         3.294215     -0.436182     -0.343385      1.220342
# 1       -0.783876         3.294215     -1.029628     -1.147585      1.220342
# 2       -1.199981        -0.303562     -0.554871     -1.878677     -1.818641
# 3       -1.542489         3.294215     -1.108754     -1.147585      1.220342
# 4       -0.161134        -0.303562     -0.053740     -0.416494      1.220342
#
#    PricePremium  PriceRelative
# 0     -0.802415           0.06
# 1     -0.870953           0.07
# 2     -1.018270           0.65
# 3     -1.256183           0.09
# 4      1.014233           0.07

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale_3 = min_max_scaler.fit_transform(X_3)

# %%
# shuffle and split data into train (~80%) and test (~20%)
X_train_3, X_test_3, y_train_3, y_test_3 = train_test_split(X_scale_3, Y, 
                                                    test_size=0.2, random_state=42) 

print('training data shape: ',X_train_3.shape)
print('testing data shape: ',X_test_3.shape)
# Out:
# training data shape:  (256, 7)
# testing data shape:  (64, 7)

# %%
#get number of columns in training data
n_cols_3 = X_train_3.shape[1]

# builds model
model_3 = keras.Sequential()

model_3.add(keras.layers.Dense(150, activation=tf.nn.relu, 
                       input_shape=(n_cols_3,)))
model_3.add(keras.layers.Dense(150, activation=tf.nn.relu))
model_3.add(keras.layers.Dense(150, activation=tf.nn.relu))
model_3.add(keras.layers.Dense(150, activation=tf.nn.relu))
model_3.add(keras.layers.Dense(150, activation=tf.nn.relu))
model_3.add(keras.layers.Dense(1))

#compile model
model_3.compile(loss='mse', optimizer='adam', metrics=['mae']) # use metric as mean absolute error

#inspect the model
model_3.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_42 (Dense)             (None, 150)               1200
# _________________________________________________________________
# dense_43 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_44 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_45 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_46 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_47 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 91,951
# Trainable params: 91,951
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train model and perform validation test

early_stop_3 = EarlyStopping(monitor='val_loss', patience=15) # stops training when it doesn't show improvemnet.

history_3 = model_3.fit(X_train_3, y_train_3, epochs=300, 
          validation_split=0.2, verbose=1, callbacks=[early_stop_3])
# Out:
# Train on 204 samples, validate on 52 samples
# Epoch 1/300
# 204/204 [==============================] - 0s 2ms/sample - loss: 0.8639 - mean_absolute_error: 0.7830 - val_loss: 0.6315 - val_mean_absolute_error: 0.6516
# Epoch 2/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.4906 - mean_absolute_error: 0.5619 - val_loss: 0.2542 - val_mean_absolute_error: 0.4017
# Epoch 3/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.1810 - mean_absolute_error: 0.3387 - val_loss: 0.1395 - val_mean_absolute_error: 0.3097
# Epoch 4/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0785 - mean_absolute_error: 0.2217 - val_loss: 0.0638 - val_mean_absolute_error: 0.2088
# Epoch 5/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0485 - mean_absolute_error: 0.1761 - val_loss: 0.0408 - val_mean_absolute_error: 0.1642
# Epoch 6/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0297 - mean_absolute_error: 0.1332 - val_loss: 0.0316 - val_mean_absolute_error: 0.1439
# Epoch 7/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0248 - mean_absolute_error: 0.1261 - val_loss: 0.0217 - val_mean_absolute_error: 0.1183
# Epoch 8/300
# 204/204 [==============================] - 0s 249us/sample - loss: 0.0180 - mean_absolute_error: 0.1071 - val_loss: 0.0156 - val_mean_absolute_error: 0.1009
# Epoch 9/300
# 204/204 [==============================] - 0s 293us/sample - loss: 0.0157 - mean_absolute_error: 0.0985 - val_loss: 0.0134 - val_mean_absolute_error: 0.0944
# Epoch 10/300
# 204/204 [==============================] - 0s 218us/sample - loss: 0.0133 - mean_absolute_error: 0.0944 - val_loss: 0.0091 - val_mean_absolute_error: 0.0756
# Epoch 11/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0082 - mean_absolute_error: 0.0700 - val_loss: 0.0064 - val_mean_absolute_error: 0.0624
# Epoch 12/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0063 - mean_absolute_error: 0.0616 - val_loss: 0.0052 - val_mean_absolute_error: 0.0562
# Epoch 13/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0050 - mean_absolute_error: 0.0542 - val_loss: 0.0053 - val_mean_absolute_error: 0.0579
# Epoch 14/300
# 204/204 [==============================] - 0s 239us/sample - loss: 0.0039 - mean_absolute_error: 0.0466 - val_loss: 0.0045 - val_mean_absolute_error: 0.0548
# Epoch 15/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0042 - mean_absolute_error: 0.0503 - val_loss: 0.0035 - val_mean_absolute_error: 0.0417
# Epoch 16/300
# 204/204 [==============================] - 0s 355us/sample - loss: 0.0037 - mean_absolute_error: 0.0446 - val_loss: 0.0041 - val_mean_absolute_error: 0.0491
# Epoch 17/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0030 - mean_absolute_error: 0.0405 - val_loss: 0.0031 - val_mean_absolute_error: 0.0436
# Epoch 18/300
# 204/204 [==============================] - 0s 235us/sample - loss: 0.0027 - mean_absolute_error: 0.0372 - val_loss: 0.0026 - val_mean_absolute_error: 0.0356
# Epoch 19/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0021 - mean_absolute_error: 0.0336 - val_loss: 0.0025 - val_mean_absolute_error: 0.0353
# Epoch 20/300
# 204/204 [==============================] - 0s 235us/sample - loss: 0.0019 - mean_absolute_error: 0.0324 - val_loss: 0.0026 - val_mean_absolute_error: 0.0352
# Epoch 21/300
# 204/204 [==============================] - 0s 255us/sample - loss: 0.0021 - mean_absolute_error: 0.0341 - val_loss: 0.0030 - val_mean_absolute_error: 0.0427
# Epoch 22/300
# 204/204 [==============================] - 0s 255us/sample - loss: 0.0030 - mean_absolute_error: 0.0433 - val_loss: 0.0021 - val_mean_absolute_error: 0.0330
# Epoch 23/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0027 - mean_absolute_error: 0.0391 - val_loss: 0.0027 - val_mean_absolute_error: 0.0357
# Epoch 24/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.
-04 - mean_absolute_error: 0.0182 - val_loss: 0.0014 - val_mean_absolute_error: 0.0277
# Epoch 99/300
# 204/204 [==============================] - 0s 130us/sample - loss: 0.0011 - mean_absolute_error: 0.0271 - val_loss: 0.0020 - val_mean_absolute_error: 0.0378
# Epoch 100/300
# 204/204 [==============================] - 0s 157us/sample - loss: 0.0014 - mean_absolute_error: 0.0304 - val_loss: 0.0025 - val_mean_absolute_error: 0.0427
# Epoch 101/300
# 204/204 [==============================] - 0s 152us/sample - loss: 0.0011 - mean_absolute_error: 0.0264 - val_loss: 0.0036 - val_mean_absolute_error: 0.0558
# Epoch 102/300
# 204/204 [==============================] - 0s 106us/sample - loss: 0.0019 - mean_absolute_error: 0.0348 - val_loss: 0.0016 - val_mean_absolute_error: 0.0267
# Epoch 103/300
# 204/204 [==============================] - 0s 159us/sample - loss: 6.0436e-04 - mean_absolute_error: 0.0181 - val_loss: 9.2675e-04 - val_mean_absolute_error: 0.0212
# Epoch 104/300
# 204/204 [==============================] - 0s 214us/sample - loss: 4.2200e-04 - mean_absolute_error: 0.0162 - val_loss: 9.9208e-04 - val_mean_absolute_error: 0.0240
# Epoch 105/300
# 204/204 [==============================] - 0s 186us/sample - loss: 4.1262e-04 - mean_absolute_error: 0.0156 - val_loss: 9.6417e-04 - val_mean_absolute_error: 0.0217
# Epoch 106/300
# 204/204 [==============================] - 0s 148us/sample - loss: 9.7726e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0015 - val_mean_absolute_error: 0.0288
# Epoch 107/300
# 204/204 [==============================] - 0s 219us/sample - loss: 7.7621e-04 - mean_absolute_error: 0.0210 - val_loss: 0.0019 - val_mean_absolute_error: 0.0338

# %%
# show the graph of model loss in trainig and validation 

plt.figure(figsize=(15,8))
plt.xlabel('Epoch')
plt.ylabel('Mean Square Error')
plt.plot(history_3.epoch, history_3.history['loss'],
           label='Train Loss')
plt.plot(history_3.epoch, history_3.history['val_loss'],
           label = 'Val loss')
plt.title('Model loss')
plt.legend()
plt.savefig('Figures/model_loss_3.png',dpi=1000,bbox_inches='tight')

# %%
#check the model performace in test dataset
score_3 = model_3.evaluate(X_test_3, y_test_3, verbose=1)
print('loss value: ', score_3[0])
print('Mean absolute error: ', score_3[1])
# Out:
# 64/64 [==============================] - 0s 125us/sample - loss: 0.0045 - mean_absolute_error: 0.0485
# loss value:  0.004483237746171653
# Mean absolute error:  0.048533753

# %%
'''=== predict the house price ==='''

# predict house price using the test data 
test_predictions_3 = model_3.predict(X_test_3).flatten()
print(test_predictions_3)
# Out:
# [ 2.0641441   0.5774395   1.6625654  -0.72300863  0.57619065  1.7850276
#   1.9106455  -1.0307091   0.5199248   0.7100631  -1.065715    0.6932895
#  -0.9383567  -1.1647283  -0.84387016  1.5133117   1.8872848   1.2305018
#   0.5199248   0.3173145  -1.080279   -0.826353   -1.2147193  -0.88638324
#  -0.9201365   1.2228328  -1.1498165   1.226022    0.59666705 -0.95479476
#   0.33847526 -0.7565633   1.5395122   2.0228438  -0.03481512 -1.0898416
#   2.3662136   1.226022   -0.75139165  2.2705061   0.52929413 -0.45109126
#   2.0131137  -0.84387016 -0.69717973 -1.0711186  -1.2399938  -0.75139165
#   1.4618148   0.0937052  -1.1336143   0.38311186 -0.92395556 -1.2154571
#  -1.1798369   0.6995581   0.53860277 -0.70788044 -1.222202   -0.54689616
#   1.226022    1.7804981  -0.17328666 -0.12769122]

# %%
# show the true value and predicted value in dataframe
true_predicted_3 = pd.DataFrame(list(zip(y_test_3, test_predictions_3)), 
                    columns=['True Value','Predicted Value'])
true_predicted_3.head(10)
# Out:
#               True Value  Predicted Value
# 0   [1.9962017456503172]         2.064144
# 1   [0.5514604154564543]         0.577439
# 2   [1.5825364929879715]         1.662565
# 3  [-0.7564215152247422]        -0.723009
# 4   [0.5535184515393514]         0.576191
# 5   [1.7533534878684431]         1.785028
# 6   [1.8017173358165282]         1.910645
# 7  [-1.0229371879599352]        -1.030709
# 8   [0.4742840623478076]         0.519925
# 9   [0.6625943639329053]         0.710063

# %%
#visiulize the true value with predicted value (using line graph)
x_3 = test_predictions_3
y_3 = y_test_3
plt.figure(figsize=(30,10))
plt.plot(x_3, label='predicted value')
plt.plot(y_3, label='true value')
plt.title('Evaluation Result')
plt.legend()
plt.savefig('Evaluation_Result_3.png',dpi=1000,bbox_inches='tight')
plt.show()

# %%
'''=== Visualize the model evaluation skill ==='''


# visualize the prediction uisng diagonal line
y_3 = test_predictions_3 #y-axis
x_3 = y_test_3 #x-axis
fig, ax = plt.subplots(figsize=(10,6)) # create figure
ax.scatter(x_3,y_3) #scatter plots for x,y
ax.set(xlim=(0,2.5), ylim=(0, 2.5)) #set limit
ax.plot(ax.get_xlim(), ax.get_ylim(), color ='red') # draw 45 degree diagonal in figure
plt.xlabel('True Values')
plt.ylabel('Predicted values')
plt.title('Evaluation Result')
plt.savefig('x_Evaluation_Result_3.png',dpi=1000,bbox_inches='tight')
plt.show()

# %% [markdown]
# ## subset_4

# %%
path = 'max_data/SixAirlinesDataV2.csv'
data_4 = pd.read_csv(path, sep = ',', na_filter = False)

data_4=data_4.drop(columns='Unnamed: 0')
data_4.head()
# Out:
#     Airline  Aircraft  FlightDuration  IsInternational  SeatsEconomy  \
# 0  0.089142 -0.693889       -0.817844         3.294215     -0.436182
# 1  0.089142 -0.693889       -0.783876         3.294215     -1.029628
# 2  0.648468 -0.693889       -1.199981        -0.303562     -0.554871
# 3  0.089142  1.441153       -1.542489         3.294215     -1.108754
# 4  1.207793 -0.693889       -0.161134        -0.303562     -0.053740
#
#    SeatsPremium  PitchEconomy  PitchPremium  WidthEconomy  WidthPremium  \
# 0     -0.343385      1.220342     -2.215259      0.302148     -1.357472
# 1     -1.147585      1.220342     -2.968588     -1.455802     -2.258698
# 2     -1.878677     -1.818641      1.551387     -1.455802      1.346207
# 3     -1.147585      1.220342     -2.968588     -1.455802     -2.258698
# 4     -0.416494      1.220342      0.044729     -1.455802     -0.456246
#
#    PriceEconomy  PricePremium  PriceRelative  SeatsTotal  PitchDifference  \
# 0     -0.578401     -0.802415           0.06   -0.442612        -2.091811
# 1     -0.667926     -0.870953           0.07   -1.098823        -2.650559
# 2     -1.010589     -1.018270           0.65   -0.794154         1.819422
# 3     -1.141274     -1.256183           0.09   -1.169131        -2.650559
# 4      1.630900      1.014233           0.07   -0.114507        -0.415569
#
#    WidthDifference  PercentPremiumSeats  month_num
# 0        -1.381970             0.009871  -1.639972
# 1        -1.381970            -0.411592  -1.639972
# 2         1.912112            -2.053194   0.282340
# 3        -1.381970            -0.297797   0.282340
# 4         0.265071            -0.457953  -0.678816

# %%
# variables seleccionadas según diferentes criterios  根据不同标准选择变量
Y = data_4[['PriceEconomy']].copy()
Y = Y.values

x_data_4 = [10,7,15,13,14,17,0,1,8,9,16,3,4,5,6]

data_4.drop(data_4.columns[x_data_4], axis=1, inplace=True)
X_4 = data_4.values

# %%
data_4.head()
# Out:
#    FlightDuration  PricePremium  PriceRelative
# 0       -0.817844     -0.802415           0.06
# 1       -0.783876     -0.870953           0.07
# 2       -1.199981     -1.018270           0.65
# 3       -1.542489     -1.256183           0.09
# 4       -0.161134      1.014233           0.07

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale_4 = min_max_scaler.fit_transform(X_4)

# %%
# shuffle and split data into train (~80%) and test (~20%)
X_train_4, X_test_4, y_train_4, y_test_4 = train_test_split(X_scale_4, Y, 
                                                    test_size=0.2, random_state=42) 

print('training data shape: ',X_train_4.shape)
print('testing data shape: ',X_test_4.shape)
# Out:
# training data shape:  (256, 3)
# testing data shape:  (64, 3)

# %%
#get number of columns in training data
n_cols_4 = X_train_4.shape[1]

# builds model
model_4 = keras.Sequential()

model_4.add(keras.layers.Dense(150, activation=tf.nn.relu, 
                       input_shape=(n_cols_4,)))
model_4.add(keras.layers.Dense(150, activation=tf.nn.relu))
model_4.add(keras.layers.Dense(150, activation=tf.nn.relu))
model_4.add(keras.layers.Dense(150, activation=tf.nn.relu))
model_4.add(keras.layers.Dense(150, activation=tf.nn.relu))
model_4.add(keras.layers.Dense(1))

#compile model
model_4.compile(loss='mse', optimizer='adam', metrics=['mae']) # use metric as mean absolute error

#inspect the model
model_4.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_48 (Dense)             (None, 150)               600
# _________________________________________________________________
# dense_49 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_50 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_51 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_52 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_53 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 91,351
# Trainable params: 91,351
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train model and perform validation test

early_stop_4 = EarlyStopping(monitor='val_loss', patience=15) # stops training when it doesn't show improvemnet.

history_4 = model_4.fit(X_train_4, y_train_4, epochs=300, 
          validation_split=0.2, verbose=1, callbacks=[early_stop_4])
# Out:
# Train on 204 samples, validate on 52 samples
# Epoch 1/300
# 204/204 [==============================] - 1s 4ms/sample - loss: 0.8662 - mean_absolute_error: 0.7890 - val_loss: 0.6509 - val_mean_absolute_error: 0.6715
# Epoch 2/300
# 204/204 [==============================] - 0s 218us/sample - loss: 0.5105 - mean_absolute_error: 0.5942 - val_loss: 0.2461 - val_mean_absolute_error: 0.4178
# Epoch 3/300
# 204/204 [==============================] - 0s 227us/sample - loss: 0.1624 - mean_absolute_error: 0.3220 - val_loss: 0.0663 - val_mean_absolute_error: 0.1926
# Epoch 4/300
# 204/204 [==============================] - 0s 176us/sample - loss: 0.0673 - mean_absolute_error: 0.1971 - val_loss: 0.1006 - val_mean_absolute_error: 0.2197
# Epoch 5/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0583 - mean_absolute_error: 0.1770 - val_loss: 0.0532 - val_mean_absolute_error: 0.1441
# Epoch 6/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0252 - mean_absolute_error: 0.1156 - val_loss: 0.0251 - val_mean_absolute_error: 0.0961
# Epoch 7/300
# 204/204 [==============================] - 0s 314us/sample - loss: 0.0207 - mean_absolute_error: 0.1144 - val_loss: 0.0161 - val_mean_absolute_error: 0.1046
# Epoch 8/300
# 204/204 [==============================] - 0s 274us/sample - loss: 0.0165 - mean_absolute_error: 0.1038 - val_loss: 0.0090 - val_mean_absolute_error: 0.0670
# Epoch 9/300
# 204/204 [==============================] - 0s 255us/sample - loss: 0.0088 - mean_absolute_error: 0.0750 - val_loss: 0.0056 - val_mean_absolute_error: 0.0485
# Epoch 10/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0067 - mean_absolute_error: 0.0628 - val_loss: 0.0066 - val_mean_absolute_error: 0.0607
# Epoch 11/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0043 - mean_absolute_error: 0.0481 - val_loss: 0.0045 - val_mean_absolute_error: 0.0477
# Epoch 12/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0036 - mean_absolute_error: 0.0442 - val_loss: 0.0037 - val_mean_absolute_error: 0.0466
# Epoch 13/300
# 204/204 [==============================] - 0s 255us/sample - loss: 0.0026 - mean_absolute_error: 0.0386 - val_loss: 0.0026 - val_mean_absolute_error: 0.0293
# Epoch 14/300
# 204/204 [==============================] - 0s 314us/sample - loss: 0.0018 - mean_absolute_error: 0.0288 - val_loss: 0.0022 - val_mean_absolute_error: 0.0315
# Epoch 15/300
# 204/204 [==============================] - 0s 255us/sample - loss: 0.0016 - mean_absolute_error: 0.0281 - val_loss: 0.0017 - val_mean_absolute_error: 0.0259
# Epoch 16/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0014 - mean_absolute_error: 0.0249 - val_loss: 0.0015 - val_mean_absolute_error: 0.0250
# Epoch 17/300
# 204/204 [==============================] - 0s 235us/sample - loss: 0.0013 - mean_absolute_error: 0.0252 - val_loss: 0.0013 - val_mean_absolute_error: 0.0217
# Epoch 18/300
# 204/204 [==============================] - 0s 235us/sample - loss: 0.0011 - mean_absolute_error: 0.0224 - val_loss: 0.0012 - val_mean_absolute_error: 0.0207
# Epoch 19/300
# 204/204 [==============================] - 0s 255us/sample - loss: 9.8390e-04 - mean_absolute_error: 0.0212 - val_loss: 0.0010 - val_mean_absolute_error: 0.0190
# Epoch 20/300
# 204/204 [==============================] - 0s 196us/sample - loss: 0.0015 - mean_absolute_error: 0.0293 - val_loss: 0.0017 - val_mean_absolute_error: 0.0312
# Epoch 21/300
# 204/204 [==============================] - 0s 216us/sample - loss: 0.0014 - mean_absolute_error: 0.0272 - val_loss: 0.0014 - val_mean_absolute_error: 0.0256
# Epoch 22/300
# 204/204 [==============================] - 0s 216us/sample - loss: 7.7990e-04 - mean_absolute_error: 0.0199 - val_loss: 7.8572e-04 - val_mean_absolute_error: 0.0179
# Epoch 23/300
# 204/204 [==============================] - 0s 176us/sample - loss: 7.9489e-04 - mean_absolute_error: 0.0201 - val_loss: 0.0011 - val_mean_absolute_error: 0.0220
# Epoch 24/300
# 204/204 [==============================] - 0s 196us/sample - loss: 7.7693e-04 - mean_absolute_error: 0.0204 - val_loss: 0.0010 - val_mean_absolute_error: 0.0267
# 204/204 [==============================] - 0s 235us/sample - loss: 7.3095e-04 - mean_absolute_error: 0.0220 - val_loss: 4.2796e-04 - val_mean_absolute_error: 0.0162
# Epoch 42/300
# 204/204 [==============================] - 0s 274us/sample - loss: 5.4563e-04 - mean_absolute_error: 0.0190 - val_loss: 6.3624e-04 - val_mean_absolute_error: 0.0215
# Epoch 43/300
# 204/204 [==============================] - 0s 196us/sample - loss: 4.3647e-04 - mean_absolute_error: 0.0159 - val_loss: 7.8348e-04 - val_mean_absolute_error: 0.0236
# Epoch 44/300
# 204/204 [==============================] - 0s 157us/sample - loss: 4.2346e-04 - mean_absolute_error: 0.0160 - val_loss: 3.0802e-04 - val_mean_absolute_error: 0.0136
# Epoch 45/300
# 204/204 [==============================] - 0s 235us/sample - loss: 5.8467e-04 - mean_absolute_error: 0.0191 - val_loss: 5.6745e-04 - val_mean_absolute_error: 0.0199
# Epoch 46/300
# 204/204 [==============================] - 0s 255us/sample - loss: 3.5193e-04 - mean_absolute_error: 0.0155 - val_loss: 3.6717e-04 - val_mean_absolute_error: 0.0155
# Epoch 47/300
# 204/204 [==============================] - 0s 235us/sample - loss: 3.9954e-04 - mean_absolute_error: 0.0157 - val_loss: 7.4849e-04 - val_mean_absolute_error: 0.0228
# Epoch 48/300
# 204/204 [==============================] - 0s 392us/sample - loss: 4.9488e-04 - mean_absolute_error: 0.0175 - val_loss: 2.8280e-04 - val_mean_absolute_error: 0.0132
# Epoch 49/300
# 204/204 [==============================] - 0s 235us/sample - loss: 3.5728e-04 - mean_absolute_error: 0.0147 - val_loss: 3.6953e-04 - val_mean_absolute_error: 0.0144
# Epoch 50/300
# 204/204 [==============================] - 0s 392us/sample - loss: 3.2225e-04 - mean_absolute_error: 0.0137 - val_loss: 3.5339e-04 - val_mean_absolute_error: 0.0143
# Epoch 51/300
# 204/204 [==============================] - 0s 216us/sample - loss: 1.6908e-04 - mean_absolute_error: 0.0098 - val_loss: 2.9958e-04 - val_mean_absolute_error: 0.0136
# Epoch 52/300
# 204/204 [==============================] - 0s 235us/sample - loss: 2.3935e-04 - mean_absolute_error: 0.0114 - val_loss: 2.8808e-04 - val_mean_absolute_error: 0.0141

# %%
# show the graph of model loss in trainig and validation 

plt.figure(figsize=(15,8))
plt.xlabel('Epoch')
plt.ylabel('Mean Square Error')
plt.plot(history_4.epoch, history_4.history['loss'],
           label='Train Loss')
plt.plot(history_4.epoch, history_4.history['val_loss'],
           label = 'Val loss')
plt.title('Model loss')
plt.legend()
plt.savefig('Figures/model_loss_4.png',dpi=1000,bbox_inches='tight')

# %%
#check the model performace in test dataset
score_4 = model_4.evaluate(X_test_4, y_test_4, verbose=1)
print('loss value: ', score_4[0])
print('Mean absolute error: ', score_4[1])
# Out:
# 64/64 [==============================] - 0s 0s/sample - loss: 3.3909e-04 - mean_absolute_error: 0.0137
# loss value:  0.0003390892961760983
# Mean absolute error:  0.013673462

# %%
'''=== predict the house price ==='''

# predict house price using the test data 
test_predictions_4 = model_4.predict(X_test_4).flatten()
print(test_predictions_4)
# Out:
# [ 1.9977338   0.5423366   1.6000383  -0.7531435   0.5103737   1.7581074
#   1.814354   -1.0351386   0.49029005  0.66813886 -1.1508602   0.6282423
#  -0.97591245 -1.1585344  -0.9049246   1.441067    1.811995    1.1861482
#   0.49029005  0.29752085 -1.1226743  -0.6449128  -1.1940479  -0.90448415
#  -0.9082095   1.1280155  -1.1354297   1.1418184   0.555464   -1.0046438
#   0.2918709  -0.790256    1.4759122   1.9605364  -0.04942264 -1.0722406
#   2.3533006   1.1418184  -0.77818865  2.198206    0.50459576 -0.46155125
#   1.6280628  -0.9049246  -0.77716696 -1.1454028  -1.2140008  -0.77818865
#   1.4008149   0.02034215 -1.1621462   0.34879404 -0.91328424 -1.1742258
#  -1.1513779   0.65384996  0.5152772  -0.7499475  -1.243272   -0.5453337
#   1.1418184   1.7583519  -0.26289865 -0.22000782]

# %%
# show the true value and predicted value in dataframe
true_predicted_4 = pd.DataFrame(list(zip(y_test_4, test_predictions_4)), 
                    columns=['True Value','Predicted Value'])
true_predicted_4.head(10)
# Out:
#               True Value  Predicted Value
# 0   [1.9962017456503172]         1.997734
# 1   [0.5514604154564543]         0.542337
# 2   [1.5825364929879715]         1.600038
# 3  [-0.7564215152247422]        -0.753143
# 4   [0.5535184515393514]         0.510374
# 5   [1.7533534878684431]         1.758107
# 6   [1.8017173358165282]         1.814354
# 7  [-1.0229371879599352]        -1.035139
# 8   [0.4742840623478076]         0.490290
# 9   [0.6625943639329053]         0.668139

# %%
# show the true value and predicted value in dataframe
true_predicted_4 = pd.DataFrame(list(zip(y_test_4, test_predictions_4)), 
                    columns=['True Value','Predicted Value'])
true_predicted_4.head(10)
# Out:
#               True Value  Predicted Value
# 0   [1.9962017456503172]         1.997734
# 1   [0.5514604154564543]         0.542337
# 2   [1.5825364929879715]         1.600038
# 3  [-0.7564215152247422]        -0.753143
# 4   [0.5535184515393514]         0.510374
# 5   [1.7533534878684431]         1.758107
# 6   [1.8017173358165282]         1.814354
# 7  [-1.0229371879599352]        -1.035139
# 8   [0.4742840623478076]         0.490290
# 9   [0.6625943639329053]         0.668139

# %%
#visiulize the true value with predicted value (using line graph)
x_4 = test_predictions_4
y_4 = y_test_4
plt.figure(figsize=(30,10))
plt.plot(x_4, label='predicted value')
plt.plot(y_4, label='true value')
plt.title('Evaluation Result')
plt.legend()
plt.savefig('Evaluation_Result_4.png',dpi=1000,bbox_inches='tight')
plt.show()

# %%
'''=== Visualize the model evaluation skill ==='''


# visualize the prediction uisng diagonal line
y_4 = test_predictions_4 #y-axis
x_4 = y_test_4 #x-axis
fig, ax = plt.subplots(figsize=(10,6)) # create figure
ax.scatter(x_4,y_4) #scatter plots for x,y
ax.set(xlim=(0,2.5), ylim=(0, 2.5)) #set limit
ax.plot(ax.get_xlim(), ax.get_ylim(), color ='red') # draw 45 degree diagonal in figure
plt.xlabel('True Values')
plt.ylabel('Predicted values')
plt.title('Evaluation Result')
plt.savefig('x_Evaluation_Result_4.png',dpi=1000,bbox_inches='tight')
plt.show()

# %%
import PIL.Image as Image

import os

from PIL import Image
Image.MAX_IMAGE_PIXELS = None
 

IMAGES_PATH = 'D:\\Max_Jupyter\\b_max_end_1\\2019-11-14-Max_test\\Evaluation_Result\\'  # 图片集地址

IMAGES_FORMAT = ['.png', '.PNG']  # 图片格式

IMAGE_SIZE = 256  # 每张小图片的大小

IMAGE_ROW = 1  # 图片间隔，也就是合并成一张图后，一共有几行

IMAGE_COLUMN = 5  # 图片间隔，也就是合并成一张图后，一共有几列

IMAGE_SAVE_PATH = 'final.jpg'  # 图片转换后的地址

 

# 获取图片集地址下的所有图片名称

image_names = [name for name in os.listdir(IMAGES_PATH) for item in IMAGES_FORMAT if

               os.path.splitext(name)[1] == item]

 

# 简单的对于参数的设定和实际图片集的大小进行数量判断

if len(image_names) != IMAGE_ROW * IMAGE_COLUMN:
    print("image_names",image_names)
    print("IMAGE_ROW",IMAGE_ROW)
    print("IMAGE_COLUMN",IMAGE_COLUMN)

    raise ValueError("合成图片的参数和要求的数量不能匹配！")

 

# 定义图像拼接函数

def image_compose():

    to_image = Image.new('RGB', (IMAGE_COLUMN * IMAGE_SIZE, IMAGE_ROW * IMAGE_SIZE)) #创建一个新图

    # 循环遍历，把每张图片按顺序粘贴到对应位置上

    for y in range(1, IMAGE_ROW + 1):

        for x in range(1, IMAGE_COLUMN + 1):

            from_image = Image.open(IMAGES_PATH + image_names[IMAGE_COLUMN * (y - 1) + x - 1]).resize(

                (IMAGE_SIZE, IMAGE_SIZE),Image.ANTIALIAS)

            to_image.paste(from_image, ((x - 1) * IMAGE_SIZE, (y - 1) * IMAGE_SIZE))

    return to_image.save(IMAGE_SAVE_PATH) # 保存新图

image_compose() #调用函数

# %%
'''=== Visualize the model evaluation skill ==='''


# visualize the prediction uisng diagonal line
y = test_predictions #y-axis
x = y_test #x-axis
y_1 = test_predictions_1 #y-axis
x_1 = y_test_1 #x-axis
y_2 = test_predictions_2 #y-axis
x_2 = y_test_2 #x-axis
y_3 = test_predictions_3 #y-axis
x_3 = y_test_3 #x-axis
y_4 = test_predictions_4 #y-axis
x_4 = y_test_4 #x-axis
fig, ax = plt.subplots(figsize=(10,6)) # create figure
ax.scatter(x,y,marker = 'o',alpha=0.5) #scatter plots for x,y   subset_0
ax.scatter(x_1,y_1,c='yellow',marker = '+') #scatter plots for x,y  subset_1  subset_2  subset_3   subset_4
ax.scatter(x_2,y_2,marker = '<') #scatter plots for x,y
ax.scatter(x_3,y_3,c='blue',marker = 'x') #scatter plots for x,y
ax.scatter(x_4,y_4,c='magenta',marker = '8') #scatter plots for x,y
ax.set(xlim=(0,2.5), ylim=(0, 2.5)) #set limit
ax.plot(ax.get_xlim(), ax.get_ylim(), color ='black') # draw 45 degree diagonal in figure
plt.xlabel('True Values')
plt.ylabel('Predicted values')
plt.legend(["line","subset_0","subset_1","subset_2","subset_3","subset_4"])
plt.title('Evaluation Result')
plt.savefig('x_Evaluation_Result_all.png',dpi=1000,bbox_inches='tight')
plt.show()
