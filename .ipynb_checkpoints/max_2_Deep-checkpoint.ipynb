# %%
import time
import os


import numpy as np
import pandas as pd

import datetime as dt
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import GridSearchCV,train_test_split



from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.externals import joblib

from sklearn.linear_model import LinearRegression
from sklearn import svm
from sklearn.ensemble import RandomForestRegressor

from sklearn.ensemble import GradientBoostingRegressor

from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# ### The Data

# %%
path = 'max_data/SixAirlinesDataV2.csv'
data = pd.read_csv(path, sep = ',', na_filter = False)
#data = data.set_index('id')
data=data.drop(columns='Unnamed: 0')
data.head()
# Out:
#     Airline  Aircraft  FlightDuration  IsInternational  SeatsEconomy  \
# 0  0.089142 -0.693889       -0.817844         3.294215     -0.436182
# 1  0.089142 -0.693889       -0.783876         3.294215     -1.029628
# 2  0.648468 -0.693889       -1.199981        -0.303562     -0.554871
# 3  0.089142  1.441153       -1.542489         3.294215     -1.108754
# 4  1.207793 -0.693889       -0.161134        -0.303562     -0.053740
#
#    SeatsPremium  PitchEconomy  PitchPremium  WidthEconomy  WidthPremium  \
# 0     -0.343385      1.220342     -2.215259      0.302148     -1.357472
# 1     -1.147585      1.220342     -2.968588     -1.455802     -2.258698
# 2     -1.878677     -1.818641      1.551387     -1.455802      1.346207
# 3     -1.147585      1.220342     -2.968588     -1.455802     -2.258698
# 4     -0.416494      1.220342      0.044729     -1.455802     -0.456246
#
#    PriceEconomy  PricePremium  PriceRelative  SeatsTotal  PitchDifference  \
# 0     -0.578401     -0.802415           0.06   -0.442612        -2.091811
# 1     -0.667926     -0.870953           0.07   -1.098823        -2.650559
# 2     -1.010589     -1.018270           0.65   -0.794154         1.819422
# 3     -1.141274     -1.256183           0.09   -1.169131        -2.650559
# 4      1.630900      1.014233           0.07   -0.114507        -0.415569
#
#    WidthDifference  PercentPremiumSeats  month_num
# 0        -1.381970             0.009871  -1.639972
# 1        -1.381970            -0.411592  -1.639972
# 2         1.912112            -2.053194   0.282340
# 3        -1.381970            -0.297797   0.282340
# 4         0.265071            -0.457953  -0.678816

# %% [markdown]
# The dataset that we have now is in what we call a pandas dataframe. To convert it to an array, simply access its values:

# %%
print ("Dimension of training data {}".format(data.shape))
# Out:
# Dimension of training data (320, 18)

# %%
print (data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 18 columns):
# Airline                320 non-null float64
# Aircraft               320 non-null float64
# FlightDuration         320 non-null float64
# IsInternational        320 non-null float64
# SeatsEconomy           320 non-null float64
# SeatsPremium           320 non-null float64
# PitchEconomy           320 non-null float64
# PitchPremium           320 non-null float64
# WidthEconomy           320 non-null float64
# WidthPremium           320 non-null float64
# PriceEconomy           320 non-null float64
# PricePremium           320 non-null float64
# PriceRelative          320 non-null float64
# SeatsTotal             320 non-null float64
# PitchDifference        320 non-null float64
# WidthDifference        320 non-null float64
# PercentPremiumSeats    320 non-null float64
# month_num              320 non-null float64
# dtypes: float64(18)
# memory usage: 45.1 KB
# None

# %%
data.describe()
# Out:
#             Airline      Aircraft  FlightDuration  IsInternational  \
# count  3.200000e+02  3.200000e+02    3.200000e+02     3.200000e+02
# mean  -1.864828e-16  2.914335e-17   -8.326673e-17    -2.588207e-16
# std    1.001566e+00  1.001566e+00    1.001566e+00     1.001566e+00
# min   -1.029508e+00 -6.938887e-01   -1.740634e+00    -3.035625e-01
# 25%   -1.029508e+00 -6.938887e-01   -9.169164e-01    -3.035625e-01
# 50%   -4.701827e-01 -6.938887e-01    5.116389e-02    -3.035625e-01
# 75%    6.484676e-01  1.441153e+00    8.522362e-01    -3.035625e-01
# max    1.767118e+00  1.441153e+00    2.055260e+00     3.294215e+00
#
#        SeatsEconomy  SeatsPremium  PitchEconomy  PitchPremium  WidthEconomy  \
# count  3.200000e+02  3.200000e+02  3.200000e+02  3.200000e+02  3.200000e+02
# mean   1.443290e-16  2.156695e-16  2.288100e-15  2.159167e-15  2.071260e-16
# std    1.001566e+00  1.001566e+00  1.001566e+00  1.001566e+00  1.001566e+00
# min   -1.662636e+00 -1.878677e+00 -1.818641e+00 -2.968588e+00 -1.455802e+00
# 25%   -8.779693e-01 -9.282579e-01 -2.991499e-01  4.472892e-02 -1.455802e+00
# 50%   -1.658350e-01  1.683795e-01 -2.991499e-01  4.472892e-02  3.021476e-01
# 75%    5.133302e-01  4.608162e-01  1.220342e+00  4.472892e-02  3.021476e-01
# max    2.438730e+00  2.361654e+00  2.739833e+00  1.551387e+00  2.060098e+00
#
#        WidthPremium  PriceEconomy  PricePremium  PriceRelative    SeatsTotal  \
# count  3.200000e+02  3.200000e+02  3.200000e+02     320.000000  3.200000e+02
# mean  -1.238593e-15  3.339343e-17 -1.214306e-17       0.495094 -4.737963e-17
# std    1.001566e+00  1.001566e+00  1.001566e+00       0.453322  1.001566e+00
# min   -2.258698e+00 -1.245205e+00 -1.331024e+00       0.020000 -1.637853e+00
# 25%   -4.562457e-01 -9.009986e-01 -9.912884e-01       0.107500 -8.410259e-01
# 50%   -4.562457e-01 -7.058099e-02 -1.115218e-01       0.380000 -1.203663e-01
# 75%    1.346207e+00  5.560910e-01  9.504217e-01       0.740000  4.831129e-01
# max    1.346207e+00  2.385171e+00  4.441915e+00       1.890000  2.381436e+00
#
#        PitchDifference  WidthDifference  PercentPremiumSeats     month_num
# count     3.200000e+02     3.200000e+02         3.200000e+02  3.200000e+02
# mean     -9.020562e-17    -1.068590e-16        -1.798475e-16 -7.337880e-16
# std       1.001566e+00     1.001566e+00         1.001566e+00  1.001566e+00
# min      -2.650559e+00    -1.381970e+00        -2.053194e+00 -1.639972e+00
# 25%      -4.155686e-01    -5.584499e-01        -4.579533e-01 -6.788164e-01
# 50%       1.431791e-01    -5.584499e-01        -2.619726e-01  2.823396e-01
# 75%       1.431791e-01     1.088591e+00         1.911009e-01  1.243496e+00
# max       1.819422e+00     1.912112e+00         2.157229e+00  1.243496e+00

# %%
# data visualization
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(data['PriceEconomy'])

# %%
sns.distplot(data['Airline'])

# %%
sns.distplot(data['FlightDuration'])

# %%
# variables seleccionadas según diferentes criterios  根据不同标准选择变量
Y = data[['PriceEconomy']].copy()
Y = Y.values
X = data.drop(columns = ['PriceEconomy']).copy()
X = X.values

# %%
X, Y
# Out:
# (array([[ 0.08914245, -0.69388867, -0.81784385, ..., -1.38197044,
#           0.00987147, -1.63997243],
#         [ 0.08914245, -0.69388867, -0.78387612, ..., -1.38197044,
#          -0.41159228, -1.63997243],
#         [ 0.64846763, -0.69388867, -1.1999808 , ...,  1.91211181,
#          -2.05319359,  0.28233958],
#         ...,
#         [-1.02950791,  1.44115338, -1.174505  , ..., -0.55844988,
#           0.19110088,  0.28233958],
#         [-1.02950791, -0.69388867,  0.24081705, ..., -0.55844988,
#           2.15722928,  1.24349558],
#         [-0.47018273, -0.69388867,  1.46648594, ...,  1.08859124,
#           0.11945205, -0.67881643]]), array([[-0.57840139],
#         [-0.66792596],
#         [-1.01058897],
#         [-1.14127426],
#         [ 1.63090034],
#         [-0.79243715],
#         [-1.13510015],
#         [ 0.49692246],
#         [-1.15362248],
#         [ 0.55351845],
#         [-0.49505093],
#         [-1.0064729 ],
#         [-0.98074745],
#         [-0.93855771],
#         [-0.94781887],
#         [-0.79243715],
#         [-0.83462689],
#         [-1.15156444],
#         [-0.93855771],
#         [ 2.20097634],
#         [-0.94781887],
#         [ 0.55351845],
#         [-1.21227651],
#         [-0.7214349 ],
#         [-1.24520508],
#         [ 1.58253649],
#         [ 1.54343381],
#         [ 0.20673937],
#         [ 1.11227525],
#         [ 0.79945376],
#         [-0.60206881],
#         [ 1.77084679],
#         [-1.18243498],
#         [ 1.14108775],
#         [-1.09496845],
#         [-0.60206881],
#         [-0.79243715],
#         [ 0.55351845],
#         [-1.23285687],
#         [ 0.50618362],
#         [ 1.94475084],
#         [ 0.08325721],
#         [-0.898426  ],
#         [ 0.16352061],
#         [ 0.58953408],
#         [-1.15979659],
#         [-0.73892821],
#         [ 1.20385785],
#         [-0.49196388],
#         [-0.94576083],
#         [ 0.31375725],
#         [-1.14024524],
#         [-1.00029879],
#         [ 1.94475084],
#         [-0.84183001],
#         [ 0.47428406],
#         [ 0.36726619],
#         [-1.16082561],
#         [ 0.16352061],
#         [-0.06183434],
#         [-0.72040588],
#         [-1.07747514],
#         [-1.19066713],
#         [-0.75642152],
#         [ 1.80171734],
#         [-0.02890576],
#         [-1.13612917],
#         [-0.03405085],
#         [ 1.75335349],
#         [-0.02890576],
#         [-0.03405085],
#         [-0.15238792],
#         [-0.84080099],
#         [ 0.56483765],
#         [ 0.55351845],
#         [ 0.31375725],
#         [ 0.64613008],
#         [ 1.20385785],
#         [-1.05998184],
#         [-1.01573406],
#         [-1.13510015],
#         [-1.20095731],
#         [-0.95296396],
#         [ 0.49692246],
#         [ 2.20097634],
#         [ 1.42406771],
#         [-0.156504  ],
#         [-0.64528757],
#         [ 0.38681753],
#         [-0.49505093],
#         [-1.14950641],
#         [-1.17111579],
#         [ 2.00134684],
#         [-0.3448143 ],
#         [ 0.36726619],
#         [ 0.08325721],
#         [ 0.55146042],
#         [ 1.87992271],
#         [-1.15979659],
#         [ 0.20673937],
#         [-1.14024524],
#         [-0.59177863],
#         [ 1.42406771],
#         [-1.13510015],
#         [ 0.299351  ],
#         [ 1.47346058],
#         [ 1.94475084],
#         [-1.01058897],
#         [-0.7214349 ],
#         [-0.87064252],
#         [ 1.75335349],
#         [ 1.94475084],
#         [-0.06183434],
#         [-1.17008677],
#         [-0.54753085],
#         [ 0.58953408],
#         [-1.00853094],
#         [-0.06183434],
#         [-0.72040588],
#         [ 1.42406771],
#         [ 1.99620175],
#         [ 0.73050955],
#         [ 1.42406771],
#         [ 0.50618362],
#         [ 1.94475084],
#         [-0.13901069],
#         [ 0.79945376],
#         [ 0.38681753],
#         [ 1.42406771],
#         [ 1.37055878],
#         [-1.10525863],
#         [-0.07932764],
#         [ 0.52058987],
#         [-1.15876757],
#         [ 1.93857674],
#         [-0.05257317],
#         [-0.39523618],
#         [-0.7327541 ],
#         [-0.95296396],
#         [-0.88710681],
#         [-1.16905775],
#         [ 0.48869031],
#         [-0.71320276],
#         [-1.02293719],
#         [ 1.37261681],
#         [-0.19457766],
#         [ 0.17381079],
#         [-0.9210644 ],
#         [ 1.75335349],
#         [-0.57222729],
#         [-1.23594392],
#         [-0.87681663],
#         [ 0.55351845],
#         [-0.63191033],
#         [-0.57222729],
#         [ 0.13470811],
#         [-1.18243498],
#         [ 1.94475084],
#         [ 0.34359877],
#         [-0.7327541 ],
#         [ 1.87992271],
#         [ 1.11227525],
#         [ 1.99620175],
#         [ 0.36932422],
#         [-0.97354432],
#         [ 0.47428406],
#         [ 1.63090034],
#         [ 1.99620175],
#         [ 1.47346058],
#         [-0.68541927],
#         [-1.06718496],
#         [-1.01573406],
#         [-0.88710681],
#         [-1.08982336],
#         [ 0.51750282],
#         [ 1.8336169 ],
#         [ 2.38517057],
#         [ 0.04929961],
#         [-1.14127426],
#         [-1.15362248],
#         [ 0.55146042],
#         [-0.79243715],
#         [-0.71423178],
#         [-0.9663412 ],
#         [ 0.55351845],
#         [ 0.65436222],
#         [ 1.80171734],
#         [ 0.56483765],
#         [-0.13901069],
#         [-0.3448143 ],
#         [-1.10525863],
#         [-0.24397053],
#         [-0.05257317],
#         [-0.44154199],
#         [-0.78832107],
#         [-0.75642152],
#         [ 1.93857674],
#         [ 1.93857674],
#         [-1.16905775],
#         [-1.05586577],
#         [ 1.37055878],
#         [ 0.55351845],
#         [ 1.8336169 ],
#         [-1.09908452],
#         [ 0.74491581],
#         [ 0.38681753],
#         [-0.15238792],
#         [ 1.47346058],
#         [ 1.12565248],
#         [-1.20095731],
#         [ 1.14108775],
#         [-0.65763578],
#         [-1.11966488],
#         [ 1.12565248],
#         [ 0.55351845],
#         [-0.83462689],
#         [ 0.2540742 ],
#         [-0.83462689],
#         [-0.64528757],
#         [ 0.31375725],
#         [ 0.66259436],
#         [-0.88401975],
#         [-0.78832107],
#         [ 1.34380431],
#         [ 0.66259436],
#         [-0.76362464],
#         [ 1.37261681],
#         [-1.24108901],
#         [-1.19992829],
#         [ 0.16043356],
#         [ 0.55146042],
#         [ 1.99620175],
#         [-1.09908452],
#         [-0.79243715],
#         [-0.79243715],
#         [ 0.34359877],
#         [ 0.13470811],
#         [ 0.50618362],
#         [ 0.17381079],
#         [-1.00029879],
#         [-1.15362248],
#         [-0.60206881],
#         [-0.94781887],
#         [ 0.17381079],
#         [ 0.47428406],
#         [-1.0064729 ],
#         [ 2.26889153],
#         [-0.87681663],
#         [ 0.36932422],
#         [-0.41067145],
#         [ 0.55351845],
#         [-0.7728858 ],
#         [-0.79243715],
#         [-0.15238792],
#         [ 0.58953408],
#         [-1.19066713],
#         [-0.60206881],
#         [ 0.21600053],
#         [-0.18634552],
#         [-0.05257317],
#         [-1.20095731],
#         [ 0.90647164],
#         [-1.15362248],
#         [-1.1032006 ],
#         [-0.96222512],
#         [ 0.08325721],
#         [ 0.08325721],
#         [ 0.91676182],
#         [ 0.52058987],
#         [-1.00544388],
#         [ 0.98261897],
#         [ 1.12565248],
#         [-0.03405085],
#         [-0.03405085],
#         [-1.07438809],
#         [ 0.51750282],
#         [ 1.77084679],
#         [-0.88710681],
#         [-1.18140597],
#         [-0.60206881],
#         [-1.23285687],
#         [-0.88710681],
#         [ 0.2540742 ],
#         [-0.30879867],
#         [ 1.14108775],
#         [ 1.69058339],
#         [ 0.16043356],
#         [ 0.20673937],
#         [ 0.98261897],
#         [-0.90871619],
#         [-0.70085454],
#         [ 0.36726619],
#         [-0.75642152],
#         [-0.7327541 ],
#         [ 0.27465456],
#         [ 0.52058987],
#         [ 0.16043356],
#         [-1.11966488],
#         [ 1.20385785],
#         [-1.11966488],
#         [-0.05257317],
#         [ 0.16352061],
#         [-0.49505093],
#         [-0.97868941],
#         [ 0.56380863],
#         [ 0.66259436],
#         [ 0.56483765],
#         [-0.97457334],
#         [ 0.98261897],
#         [-0.2594058 ],
#         [-0.66380989],
#         [ 0.4423845 ],
#         [ 2.26889153],
#         [ 0.20673937],
#         [ 0.29523492],
#         [-0.68541927],
#         [ 0.16352061],
#         [-0.94576083],
#         [-0.156504  ],
#         [-0.18428748]]))

# %% [markdown]
# Normalizing our data is very important, as we want the input features to be on the same order of magnitude to make our training easier. We'll use a min-max scaler from scikit-learn which scales our data to be between 0 and 1.

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
X_scale
# Out:
# array([[0.4       , 0.        , 0.24310216, ..., 0.        , 0.48998999,
#         0.        ],
#        [0.4       , 0.        , 0.25205071, ..., 0.        , 0.38988989,
#         0.        ],
#        [0.6       , 0.        , 0.14243102, ..., 1.        , 0.        ,
#         0.66666667],
#        ...,
#        [0.        , 1.        , 0.14914243, ..., 0.25      , 0.53303303,
#         0.66666667],
#        [0.        , 0.        , 0.52199851, ..., 0.25      , 1.        ,
#         1.        ],
#        [0.2       , 0.        , 0.84489187, ..., 0.75      , 0.51601602,
#         0.33333333]])

# %%
# shuffle and split data into train (~80%) and test (~20%)
X_train, X_test, y_train, y_test = train_test_split(X_scale, Y, 
                                                    test_size=0.2, random_state=42) 

print('training data shape: ',X_train.shape)
print('testing data shape: ',X_test.shape)
# Out:
# training data shape:  (256, 17)
# testing data shape:  (64, 17)

# %%
X_train
# Out:
# array([[0.2       , 0.        , 0.64578673, ..., 0.75      , 0.51351351,
#         1.        ],
#        [0.        , 1.        , 0.14914243, ..., 0.25      , 0.53303303,
#         0.66666667],
#        [0.6       , 0.        , 0.14914243, ..., 1.        , 0.        ,
#         0.        ],
#        ...,
#        [0.8       , 1.        , 0.59134974, ..., 0.25      , 0.38988989,
#         0.33333333],
#        [0.        , 0.        , 0.72706935, ..., 0.25      , 0.40990991,
#         1.        ],
#        [0.8       , 1.        , 0.52796421, ..., 0.25      , 0.38988989,
#         1.        ]])

# %% [markdown]
# ### Building and Training Our First Neural Network

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping

# %%
#get number of columns in training data
n_cols = X_train.shape[1]

# builds model
model = keras.Sequential()

model.add(keras.layers.Dense(150, activation=tf.nn.relu, 
                       input_shape=(n_cols,)))
model.add(keras.layers.Dense(150, activation=tf.nn.relu))
model.add(keras.layers.Dense(150, activation=tf.nn.relu))
model.add(keras.layers.Dense(150, activation=tf.nn.relu))
model.add(keras.layers.Dense(150, activation=tf.nn.relu))
model.add(keras.layers.Dense(1))

#compile model
model.compile(loss='mse', optimizer='adam', metrics=['mae']) # use metric as mean absolute error

#inspect the model
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 150)               2700
# _________________________________________________________________
# dense_31 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_32 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_33 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_34 (Dense)             (None, 150)               22650
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 151
# =================================================================
# Total params: 93,451
# Trainable params: 93,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train model and perform validation test

early_stop = EarlyStopping(monitor='val_loss', patience=15) # stops training when it doesn't show improvemnet.

history = model.fit(X_train, y_train, epochs=300, 
          validation_split=0.2, verbose=1, callbacks=[early_stop])
# Out:
# Train on 204 samples, validate on 52 samples
# Epoch 1/300
# 204/204 [==============================] - 1s 3ms/sample - loss: 0.8420 - mean_absolute_error: 0.7744 - val_loss: 0.6332 - val_mean_absolute_error: 0.6481
# Epoch 2/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.5005 - mean_absolute_error: 0.5785 - val_loss: 0.3917 - val_mean_absolute_error: 0.5186
# Epoch 3/300
# 204/204 [==============================] - 0s 306us/sample - loss: 0.2274 - mean_absolute_error: 0.3733 - val_loss: 0.1648 - val_mean_absolute_error: 0.3249
# Epoch 4/300
# 204/204 [==============================] - 0s 383us/sample - loss: 0.1027 - mean_absolute_error: 0.2378 - val_loss: 0.0912 - val_mean_absolute_error: 0.2371
# Epoch 5/300
# 204/204 [==============================] - 0s 383us/sample - loss: 0.0796 - mean_absolute_error: 0.2102 - val_loss: 0.0343 - val_mean_absolute_error: 0.1471
# Epoch 6/300
# 204/204 [==============================] - 0s 306us/sample - loss: 0.0468 - mean_absolute_error: 0.1720 - val_loss: 0.0296 - val_mean_absolute_error: 0.1333
# Epoch 7/300
# 204/204 [==============================] - 0s 383us/sample - loss: 0.0269 - mean_absolute_error: 0.1222 - val_loss: 0.0362 - val_mean_absolute_error: 0.1306
# Epoch 8/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.0265 - mean_absolute_error: 0.1229 - val_loss: 0.0281 - val_mean_absolute_error: 0.1311
# Epoch 9/300
# 204/204 [==============================] - 0s 306us/sample - loss: 0.0251 - mean_absolute_error: 0.1249 - val_loss: 0.0281 - val_mean_absolute_error: 0.1441
# Epoch 10/300
# 204/204 [==============================] - 0s 306us/sample - loss: 0.0268 - mean_absolute_error: 0.1323 - val_loss: 0.0187 - val_mean_absolute_error: 0.1114
# Epoch 11/300
# 204/204 [==============================] - 0s 306us/sample - loss: 0.0175 - mean_absolute_error: 0.1040 - val_loss: 0.0168 - val_mean_absolute_error: 0.1052
# Epoch 12/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.0147 - mean_absolute_error: 0.0961 - val_loss: 0.0174 - val_mean_absolute_error: 0.1069
# Epoch 13/300
# 204/204 [==============================] - 0s 383us/sample - loss: 0.0102 - mean_absolute_error: 0.0806 - val_loss: 0.0122 - val_mean_absolute_error: 0.0866
# Epoch 14/300
# 204/204 [==============================] - 0s 306us/sample - loss: 0.0077 - mean_absolute_error: 0.0686 - val_loss: 0.0098 - val_mean_absolute_error: 0.0762
# Epoch 15/300
# 204/204 [==============================] - 0s 306us/sample - loss: 0.0081 - mean_absolute_error: 0.0724 - val_loss: 0.0099 - val_mean_absolute_error: 0.0789
# Epoch 16/300
# 204/204 [==============================] - 0s 306us/sample - loss: 0.0074 - mean_absolute_error: 0.0692 - val_loss: 0.0137 - val_mean_absolute_error: 0.0951
# Epoch 17/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.0075 - mean_absolute_error: 0.0693 - val_loss: 0.0117 - val_mean_absolute_error: 0.0903
# Epoch 18/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.0149 - mean_absolute_error: 0.1005 - val_loss: 0.0190 - val_mean_absolute_error: 0.1103
# Epoch 19/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.0128 - mean_absolute_error: 0.0919 - val_loss: 0.0154 - val_mean_absolute_error: 0.0997
# Epoch 20/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0100 - mean_absolute_error: 0.0792 - val_loss: 0.0111 - val_mean_absolute_error: 0.0833
# Epoch 21/300
# 204/204 [==============================] - 0s 383us/sample - loss: 0.0074 - mean_absolute_error: 0.0671 - val_loss: 0.0085 - val_mean_absolute_error: 0.0723
# Epoch 22/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.0072 - mean_absolute_error: 0.0688 - val_loss: 0.0073 - val_mean_absolute_error: 0.0634
# Epoch 23/300
# 204/204 [==============================] - 0s 306us/sample - loss: 0.0062 - mean_absolute_error: 0.0628 - val_loss: 0.0091 - val_mean_absolute_error: 0.0781
# Epoch 24/300
# 204/204 [==============================] - 0s 306us/sample - loss: 0.0058 - mean_absolute_error: 0.0601 - val_loss: 0.0068 - val_mean_absolute_error: 0.0600
# Epoch 25/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.0062 - mean_absolute_error: 0.0637 - val_loss: 0.0123 - val_mean_absolute_error: 0.0897
# Epoch 26/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0054 - mean_absolute_error: 0.0582 - val_loss: 0.0071 - val_mean_absolute_error: 0.0633
# Epoch 27/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0037 - mean_absolute_error: 0.0480 - val_loss: 0.0061 - val_mean_absolute_error: 0.0594
# Epoch 28/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.0037 - mean_absolute_error: 0.0487 - val_loss: 0.0062 - val_mean_absolute_error: 0.0610
# Epoch 29/300
# 204/204 [==============================] - 0s 536us/sample - loss: 0.0041 - mean_absolute_error: 0.0523 - val_loss: 0.0074 - val_mean_absolute_error: 0.0663
# Epoch 30/300
# 204/204 [==============================] - 0s 306us/sample - loss: 0.0043 - mean_absolute_error: 0.0507 - val_loss: 0.0097 - val_mean_absolute_error: 0.0792
# Epoch 31/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0033 - mean_absolute_error: 0.0464 - val_loss: 0.0054 - val_mean_absolute_error: 0.0559
# Epoch 32/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.0028 - mean_absolute_error: 0.0422 - val_loss: 0.0050 - val_mean_absolute_error: 0.0546
# Epoch 33/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0030 - mean_absolute_error: 0.0422 - val_loss: 0.0062 - val_mean_absolute_error: 0.0631
# Epoch 34/300
# 204/204 [==============================] - 0s 306us/sample - loss: 0.0039 - mean_absolute_error: 0.0493 - val_loss: 0.0068 - val_mean_absolute_error: 0.0642
# Epoch 35/300
# 204/204 [==============================] - 0s 306us/sample - loss: 0.0040 - mean_absolute_error: 0.0511 - val_loss: 0.0078 - val_mean_absolute_error: 0.0702
# Epoch 36/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.0039 - mean_absolute_error: 0.0488 - val_loss: 0.0054 - val_mean_absolute_error: 0.0569
# Epoch 37/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.0022 - mean_absolute_error: 0.0356 - val_loss: 0.0047 - val_mean_absolute_error: 0.0532
# Epoch 38/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0022 - mean_absolute_error: 0.0368 - val_loss: 0.0058 - val_mean_absolute_error: 0.0625
# Epoch 39/300
# 204/204 [==============================] - 0s 306us/sample - loss: 0.0039 - mean_absolute_error: 0.0497 - val_loss: 0.0089 - val_mean_absolute_error: 0.0741
# Epoch 40/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.0037 - mean_absolute_error: 0.0502 - val_loss: 0.0085 - val_mean_absolute_error: 0.0703
# Epoch 41/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0028 - mean_absolute_error: 0.0393 - val_loss: 0.0038 - val_mean_absolute_error: 0.0484
# Epoch 42/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0022 - mean_absolute_error: 0.0382 - val_loss: 0.0082 - val_mean_absolute_error: 0.0725
# Epoch 43/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.0027 - mean_absolute_error: 0.0410 - val_loss: 0.0163 - val_mean_absolute_error: 0.1103
# Epoch 44/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.0061 - mean_absolute_error: 0.0612 - val_loss: 0.0128 - val_mean_absolute_error: 0.0918
# Epoch 45/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0066 - mean_absolute_error: 0.0669 - val_loss: 0.0063 - val_mean_absolute_error: 0.0614
# Epoch 46/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0053 - mean_absolute_error: 0.0562 - val_loss: 0.0049 - val_mean_absolute_error: 0.0534
# Epoch 47/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0041 - mean_absolute_error: 0.0514 - val_loss: 0.0086 - val_mean_absolute_error: 0.0772
# Epoch 48/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.0052 - mean_absolute_error: 0.0570 - val_loss: 0.0045 - val_mean_absolute_error: 0.0508
# Epoch 49/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0024 - mean_absolute_error: 0.0379 - val_loss: 0.0049 - val_mean_absolute_error: 0.0560
# Epoch 50/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0021 - mean_absolute_error: 0.0353 - val_loss: 0.0072 - val_mean_absolute_error: 0.0653
# Epoch 51/300
# 204/204 [==============================] - 0s 77us/sample - loss: 0.0025 - mean_absolute_error: 0.0402 - val_loss: 0.0054 - val_mean_absolute_error: 0.0596
# Epoch 52/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0020 - mean_absolute_error: 0.0351 - val_loss: 0.0050 - val_mean_absolute_error: 0.0547
# Epoch 53/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.0017 - mean_absolute_error: 0.0329 - val_loss: 0.0050 - val_mean_absolute_error: 0.0538
# Epoch 54/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.0022 - mean_absolute_error: 0.0363 - val_loss: 0.0083 - val_mean_absolute_error: 0.0734
# Epoch 55/300
# 204/204 [==============================] - 0s 230us/sample - loss: 0.0023 - mean_absolute_error: 0.0391 - val_loss: 0.0044 - val_mean_absolute_error: 0.0539
# Epoch 56/300
# 204/204 [==============================] - 0s 153us/sample - loss: 0.0021 - mean_absolute_error: 0.0358 - val_loss: 0.0041 - val_mean_absolute_error: 0.0492

# %%
# show the graph of model loss in trainig and validation 

plt.figure(figsize=(15,8))
plt.xlabel('Epoch')
plt.ylabel('Mean Square Error')
plt.plot(history.epoch, history.history['loss'],
           label='Train Loss')
plt.plot(history.epoch, history.history['val_loss'],
           label = 'Val loss')
plt.title('Model loss')
plt.legend()

# %%
#check the model performace in test dataset
score = model.evaluate(X_test, y_test, verbose=1)
print('loss value: ', score[0])
print('Mean absolute error: ', score[1])
# Out:
# 64/64 [==============================] - 0s 244us/sample - loss: 0.0114 - mean_absolute_error: 0.0801
# loss value:  0.011359174735844135
# Mean absolute error:  0.08008407

# %%
'''=== predict the house price ==='''

# predict house price using the test data 
test_predictions = model.predict(X_test).flatten()
print(test_predictions)
# Out:
# [ 1.9910538e+00  3.4317535e-01  1.5246940e+00 -6.2705463e-01
#   5.5694818e-01  1.2972735e+00  1.8232189e+00 -9.7745317e-01
#   3.1411901e-01  5.0137627e-01 -9.3421048e-01  7.8493255e-01
#  -8.2732630e-01 -1.0473948e+00 -9.3072557e-01  1.4701327e+00
#   1.7571155e+00  1.1958631e+00  3.0115965e-01  3.5191971e-01
#  -1.2011405e+00 -6.8338406e-01 -1.2017082e+00 -9.7964305e-01
#  -1.0167695e+00  9.9243754e-01 -1.0776726e+00  9.6336180e-01
#   5.7754743e-01 -9.0652001e-01  1.7626889e-01 -9.1781241e-01
#   1.3085414e+00  1.9210700e+00 -1.4282990e-01 -1.0322679e+00
#   2.1965146e+00  1.0001315e+00 -6.6902786e-01  2.1876333e+00
#   5.8647043e-01 -5.2654171e-01  2.2249837e+00 -7.7507538e-01
#  -7.1652395e-01 -1.0053394e+00 -1.1556551e+00 -6.1837173e-01
#   1.4237839e+00 -2.1357713e-03 -1.1297394e+00  3.2179418e-01
#  -1.1226438e+00 -1.2847583e+00 -1.1771325e+00  7.0545059e-01
#   7.3522604e-01 -7.3486954e-01 -1.2634122e+00 -6.2339991e-01
#   1.1971273e+00  1.4943733e+00 -4.2842230e-01 -3.5852529e-02]

# %%
# show the true value and predicted value in dataframe
true_predicted = pd.DataFrame(list(zip(y_test, test_predictions)), 
                    columns=['True Value','Predicted Value'])
true_predicted.head(10)
# Out:
#               True Value  Predicted Value
# 0   [1.9962017456503172]         1.991054
# 1   [0.5514604154564543]         0.343175
# 2   [1.5825364929879715]         1.524694
# 3  [-0.7564215152247422]        -0.627055
# 4   [0.5535184515393514]         0.556948
# 5   [1.7533534878684431]         1.297274
# 6   [1.8017173358165282]         1.823219
# 7  [-1.0229371879599352]        -0.977453
# 8   [0.4742840623478076]         0.314119
# 9   [0.6625943639329053]         0.501376

# %%
#visiulize the true value with predicted value (using line graph)
x = test_predictions
y = y_test
plt.figure(figsize=(30,10))
plt.plot(x, label='predicted value')
plt.plot(y, label='true value')
plt.title('Evaluation Result')
plt.legend()
plt.show()

# %%
'''=== Visualize the model evaluation skill ==='''


# visualize the prediction uisng diagonal line
y = test_predictions #y-axis
x = y_test #x-axis
fig, ax = plt.subplots(figsize=(10,6)) # create figure
ax.scatter(x,y) #scatter plots for x,y
ax.set(xlim=(0,4), ylim=(0, 4)) #set limit
ax.plot(ax.get_xlim(), ax.get_ylim(), color ='red') # draw 45 degree diagonal in figure
plt.xlabel('True Values')
plt.ylabel('Predicted values')
plt.title('Evaluation Result')
plt.show()
